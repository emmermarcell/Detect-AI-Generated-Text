# %%
# Dependencies
#for model-building
from sklearn import (model_selection, 
                     preprocessing, 
                     linear_model, 
                     naive_bayes, 
                     metrics, 
                     svm,
                     decomposition,
                     ensemble)

from scipy.sparse import csr_matrix
import joblib
import shortuuid

from sklearn.metrics import (classification_report, 
                             f1_score, 
                             accuracy_score, 
                             confusion_matrix)
from sklearn.metrics import (roc_curve, 
                             auc, 
                             roc_auc_score)

# bag of words
from sklearn.feature_extraction.text import (TfidfVectorizer, 
                                             CountVectorizer)

from itertools import cycle
import pandas as pd
import numpy as np
import tensorflow as tf
import xgboost, textblob, string, distinctipy

from keras.preprocessing import text, sequence
from keras.callbacks import EarlyStopping, ModelCheckpoint

from keras import layers, models, optimizers
import tensorflow as tf

import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm

#for text pre-processing
import re, string
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import SnowballStemmer
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# 2024-01-23 02:29:34.798113: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-23 02:29:34.798230: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-23 02:29:34.834890: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-23 02:29:34.922802: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-23 02:29:36.051149: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/syntax_error/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/syntax_error/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/syntax_error/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/syntax_error/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# 2024-01-23 02:29:37.588981: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# Num GPUs Available:  1
# 2024-01-23 02:29:37.771727: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-23 02:29:37.771941: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %%
# gpus = tf.config.list_physical_devices('GPU')
# x = 4
# if gpus:
#   # Restrict TensorFlow to only allocate x amount of GB of memory on the first GPU
#   try:
#     GBs = x * 1024
#     tf.config.set_logical_device_configuration(
#         gpus[0],
#         [tf.config.LogicalDeviceConfiguration(memory_limit=GBs)])
#     logical_gpus = tf.config.list_logical_devices('GPU')
#     print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
#   except RuntimeError as e:
#     # Virtual devices must be set before GPUs have been initialized
#     print(e)

# %% [markdown]
# # AI in data science - final project
# Kristóf Benedek, Marcell Emmer, Izabell Járó, Lin Ruihan
#
# ## Motivation
#
# In recent years, large language models (LLMs) have become increasingly sophisticated, capable of generating text that is difficult to distinguish from human-written text. The topic is not only interesting from an educational point of view, but has implications in business live as well, where AI can be used for writing ads, articles, reviews etc., and could enable plagiarism and replace humans, which can create an even increased unemployement rate and even end professions with long history like journalist, reporter, etc.
#
# This notebook was made for the project of the course BMETE15MF75 at Budapest University of Technology and Economy.
#
# In this notebook we will implement several different approaches to **text classification**. The goal is to successfully identify human written and AI-written (by LLMs) texts. The idea of the project came from the [LLM - Detect AI Generated Text](https://www.kaggle.com/competitions/llm-detect-ai-generated-text) kaggle competition.
#
# ## Introduction
#
# In the case of this notebook our focus will be on essays written by middle and high school students, but the idea is quite general, and the pipeline can be easily reconfigured for other types of text as well.
#
# That being said, we will try to build a model to identify which essay was written by middle and high school students, and which was written using a large language model. With the spread of LLMs, many people fear they will replace or alter work that would usually be done by humans. Educators are especially concerned about their impact on students’ skill development, though many remain optimistic that LLMs will ultimately be a useful tool to help students improve their writing skills.
#
# At the forefront of academic concerns about LLMs is their potential to enable plagiarism. LLMs are trained on a massive dataset of text and code, which means that they are able to generate text that is very similar to human-written text. For example, students could use LLMs to generate essays that are not their own, missing crucial learning keystones. Your work on this competition can help identify telltale LLM artifacts and advance the state of the art in LLM text detection. By using texts of moderate length on a variety of subjects and multiple, unknown generative models, we aim to replicate typical detection scenarios and incentivize learning features that generalize across models. (source [kaggle](https://www.kaggle.com/competitions/llm-detect-ai-generated-text))
#
# ## Resources
#
# When dealing with natural language processing (NLP), there are a large number of sources that can be used for learning and getting familiar with the topic. We used the following ones in creating this notebook:
#
# 1. kaggle, [Explained LLM Model](https://www.kaggle.com/code/zulqarnainali/explained-llm-model)
# 2. Abubakar Abid, Matthew Carrigan, Lysandre Debut, Sylvain Gugger, Dawood Khan, Merve Noyan, Lucile Saulnier, Lewis Tunstall, Leandro von Werra, [NLP course, Hugging Face](https://huggingface.co/learn/nlp-course/chapter0/1?fw=tf)
# 3. Shivam Bansal, [A Comprehensive Guide to Understand and Implement Text Classification in Python](https://www.analyticsvidhya.com/blog/2018/04/a-comprehensive-guide-to-understand-and-implement-text-classification-in-python/)
# 4. Vijaya Rani, [NLP Tutorial for Text Classification in Python](https://medium.com/analytics-vidhya/nlp-tutorial-for-text-classification-in-python-8f19cd17b49e)
# 5. Saravana Kumar, [Machine Learning Model for Distinguishing Human vs. ChatGPT Text](https://github.com/saro0307/AI-detector)

# %% [markdown]
# # Loading the data
#
# Here we just will load the already pre-processed data. The pre-processing is done in the notebook ```scripts/preprocess_database_for_classifiers_ML.ipynb```

# %%
df_train = pd.read_csv(r'daigt_v2_train_preproc_NLP_aug_v1.csv')
df_train = df_train.drop_duplicates(subset=['text'])
df_train.reset_index(drop=True, inplace=True)

# %%
df_train.head()
# Out:
#    Unnamed: 0                                               text  label  \
# 0           0   Dear Senator [Name],\n\nI hope this message f...      1
# 1           1   Dear Senator [Name],\n\nI am writing to expre...      1
# 2           2   Dear Senator,\n\nI am writing to express my v...      1
# 3           3   The electoral college is a group of electors ...      1
# 4           4   The cowboy's boots clanked against the wooden...      1
#
#                         prompt_name                              source  \
# 0  Does the electoral college work?  mistralai/Mistral-7B-Instruct-v0.1
# 1  Does the electoral college work?  mistralai/Mistral-7B-Instruct-v0.1
# 2  Does the electoral college work?  mistralai/Mistral-7B-Instruct-v0.1
# 3  Does the electoral college work?  mistralai/Mistral-7B-Instruct-v0.1
# 4     "A Cowboy Who Rode the Waves"  mistralai/Mistral-7B-Instruct-v0.1
#
#    RDizzl3_seven  word_count  char_count  unique_word_count  \
# 0           True         611        3667                249
# 1           True         629        4086                302
# 2           True         611        3823                260
# 3           True         416        2493                194
# 4           True        1298        7066                486
#
#                                           clean_text  word_density  \
# 0  dear senator name hope message find well recen...      5.991830
# 1  dear senator name write express thought electo...      6.485714
# 2  dear senator write express viewpoint electoral...      6.246732
# 3  electoral college group elector ultimately sel...      5.978417
# 4  cowboy boot clank wooden floorboard dust scurr...      5.439569
#
#    punctuation_count  title_word_count  upper_case_word_count  noun_count  \
# 0                 59                42                      3         150
# 1                 76                64                      7         191
# 2                 64                37                      5         165
# 3                 34                23                      0         101
# 4                174                66                      0         304
#
#    pron_count  verb_count  adj_count  adv_count
# 0          27         103         59         39
# 1          21          87         75         34
# 2          32          94         53         41
# 3          19          64         46         25
# 4         172         229         70         67

# %%
df_train.text.iloc[1]
# Out:
# " Dear Senator [Name],\n\nI am writing to express my thoughts on the Electoral College and whether it works effectively in determining the outcome of presidential elections. As an 8th-grade student, I believe the current system is a fair and democratic way of choosing our president, but there are concerns that some may have regarding its use.\n\nFirstly, let me start by acknowledging that the idea of the Electoral College is rooted in compromise during the drafting of the US Constitution. The delegates at the constitutional convention debated whether to choose the president through the popular vote or by election in Congress. Compromise was ultimately reached, and the Electoral College was established to balance the interests of urban and rural areas, big states and small states.\n\nMoreover, the Electoral College provides for a larger role for small and rural states, which represent approximately 20% of the US population. A popular vote system would disproportionately favor states with large urban populations, potentially diminishing the impact of smaller states' voices in the election process. By having smaller states, where political sentiment may differ significantly from their state's population, has an equal influence on the election.\n\nAnother advantage of the Electoral College system is that it forces candidates to campaign in all states, not just focus on urban areas. This means that candidates cannot overlook smaller or more conservative states in favor of those where they could obtain the most votes. Instead, candidates strive to appeal to a broad range of voters across the country, making for a fairer and more representative election.\n\nWhile some argue that a popular vote system would be a more straightforward and easier way to choose the president, it would also have drawbacks. For example, urbanized regions may dominate election outcomes, leaving other voters feeling underrepresented or disenfranchised. This could exacerbate divisions among regions and lead to resentment among certain groups.\n\nOn the other hand, there are concerns that the current system is not perfect, either. One potential issue is that a candidate might win the popular vote but still lose the election due to the Electoral College. For instance, in the 2000 and 2016 presidential elections, the candidate who won the popular vote did not win the Electoral College vote, leading to disputes and challenges to the election results.\n\nFurthermore, some argue that the Electoral College favors incumbents, as political parties often have more resources and influence in maintaining support from a state's electoral votes than in winning new votes. This could create inequities in the election process and limit representation in favor of incumbents.\n\nTherefore, while the Electoral College system may not be perfect, it is a fair representation of the country's diverse states and serves to give equal weight to each state's vote. In contrast, a popular vote system would likely favor urban areas and disenfranchise small or rural states. As such, I believe that the current system is more equitable and fair.\n\nIt is important for political leaders and activists to engage in ongoing discussion about the merits and demerits of the Electoral College system. While there is always potential for improvement, I urge senators to consider the historical context of the Electoral College, its effectiveness in ensuring representation across the country, and the potential drawbacks of alternative voting methods.\n\nIn conclusion, the Electoral College works effectively in determining the outcome of presidential elections. It provides equal representation to each state, forcing candidates to campaign across all regions, and allows small states to have an equal impact on the election outcome. While concerns with the current system are valid, any alternative system would likely face its own advantages and disadvantages. As advocates for fair representation, it is importa ...

# %% [markdown]
# ## Creating a model

# %%
# split the data into train and validation sets
train_x, test_x, train_y, test_y = model_selection.train_test_split(df_train.text, df_train.label, 
                                                                    test_size = 0.2, 
                                                                    random_state = 42)

# # further split into train and validation
# train_x, valid_x, train_y, valid_y = model_selection.train_test_split(train_x, train_y, 
#                                                                     test_size = 0.1, 
#                                                                     random_state = 42)

# %% [markdown]
# ## Feature Engineering
# The next step is the feature engineering step. In this step, raw text data will be transformed into feature vectors and new features will be created using the existing dataset. We will implement the following different ideas in order to obtain relevant features from our dataset.
#
# 1. Count Vectors as features
# 2. TF-IDF Vectors as features
#    - Word level
#    - N-Gram level
#    - Character level
# 3. Word Embeddings as features
# 4. Text / NLP based features
# 5. Topic Models as features
#
# ### Count Vectors as features
# Count Vector is a matrix notation of the dataset in which every row represents a document from the corpus, every column represents a term from the corpus, and every cell represents the frequency count of a particular term in a particular document.

# %%
# create a count vectorizer object 
count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}')
count_vect.fit(df_train['text'])

# transform the training and validation data using count vectorizer object
xtrain_count =  count_vect.transform(train_x)
xtest_count =  count_vect.transform(test_x)

# %%
# # Save the CountVectorizer object and the transformed data

# joblib.dump(count_vect, 'count_vectorizer.pkl')
# joblib.dump(xtrain_count, 'xtrain_count.pkl')
# joblib.dump(xtest_count, 'xtest_count.pkl')
# Out:
# ['xtest_count.pkl']

# %%
# load them back
loaded_count_vect = joblib.load('count_vectorizer.pkl')
xtrain_count = joblib.load('xtrain_count.pkl')
xtest_count = joblib.load('xtest_count.pkl')

# %% [markdown]
# ### TF-IDF Vectors as features
# TF-IDF score represents the relative importance of a term in the document and the entire corpus. TF-IDF score is composed by two terms: the first computes the normalized Term Frequency (TF), the second term is the Inverse Document Frequency (IDF), computed as the logarithm of the number of the documents in the corpus divided by the number of documents where the specific term appears.
#
# - TF(t) = (Number of times term t appears in a document) / (Total number of terms in the document)
# - IDF(t) = log_e(Total number of documents / Number of documents with term t in it)
# - TF-IDF Vectors can be generated at different levels of input tokens (words, characters, n-grams)
#
# 1. Word Level TF-IDF : Matrix representing tf-idf scores of every term in different documents
# 2. N-gram Level TF-IDF : N-grams are the combination of N terms together. This Matrix representing tf-idf scores of N-grams
# 3. Character Level TF-IDF : Matrix representing tf-idf scores of character level n-grams

# %%
# word level tf-idf
tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', max_features=5000)
tfidf_vect.fit(df_train['text'])
xtrain_tfidf =  tfidf_vect.transform(train_x)
xtest_tfidf =  tfidf_vect.transform(test_x)

# ngram level tf-idf 
tfidf_vect_ngram = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(2,3), max_features=5000)
tfidf_vect_ngram.fit(df_train['text'])
xtrain_tfidf_ngram =  tfidf_vect_ngram.transform(train_x)
xtest_tfidf_ngram =  tfidf_vect_ngram.transform(test_x)

# characters level tf-idf
tfidf_vect_ngram_chars = TfidfVectorizer(analyzer='char', token_pattern=r'\w{1,}', ngram_range=(2,3), max_features=5000)
tfidf_vect_ngram_chars.fit(df_train['text'])
xtrain_tfidf_ngram_chars =  tfidf_vect_ngram_chars.transform(train_x) 
xtest_tfidf_ngram_chars =  tfidf_vect_ngram_chars.transform(test_x)
# Out:
# /home/syntax_error/.pyenv/versions/3.10.13/lib/python3.10/site-packages/sklearn/feature_extraction/text.py:555: UserWarning: The parameter 'token_pattern' will not be used since 'analyzer' != 'word'
#   warnings.warn(

# %%
# # Save TF-IDF vectorizers
# joblib.dump(tfidf_vect, './tfidf/tfidf_vect.joblib')
# joblib.dump(tfidf_vect_ngram, './tfidf/tfidf_vect_ngram.joblib')
# joblib.dump(tfidf_vect_ngram_chars, './tfidf/tfidf_vect_ngram_chars.joblib')

# # Save transformed data
# joblib.dump(xtrain_tfidf, './tfidf/xtrain_tfidf.joblib')
# joblib.dump(xtest_tfidf, './tfidf/xtest_tfidf.joblib')

# joblib.dump(xtrain_tfidf_ngram, './tfidf/xtrain_tfidf_ngram.joblib')
# joblib.dump(xtest_tfidf_ngram, './tfidf/xtest_tfidf_ngram.joblib')

# joblib.dump(xtrain_tfidf_ngram_chars, './tfidf/xtrain_tfidf_ngram_chars.joblib')
# joblib.dump(xtest_tfidf_ngram_chars, './tfidf/xtest_tfidf_ngram_chars.joblib')
# Out:
# ['./tfidf/xtest_tfidf_ngram_chars.joblib']

# %%
# Load TF-IDF vectorizers
tfidf_vect = joblib.load('./tfidf/tfidf_vect.joblib')
tfidf_vect_ngram = joblib.load('./tfidf/tfidf_vect_ngram.joblib')
tfidf_vect_ngram_chars = joblib.load('./tfidf/tfidf_vect_ngram_chars.joblib')

# Load transformed data
xtrain_tfidf = joblib.load('./tfidf/xtrain_tfidf.joblib')
xtest_tfidf = joblib.load('./tfidf/xtest_tfidf.joblib')

xtrain_tfidf_ngram = joblib.load('./tfidf/xtrain_tfidf_ngram.joblib')
xtest_tfidf_ngram = joblib.load('./tfidf/xtest_tfidf_ngram.joblib')

xtrain_tfidf_ngram_chars = joblib.load('./tfidf/xtrain_tfidf_ngram_chars.joblib')
xtest_tfidf_ngram_chars = joblib.load('./tfidf/xtest_tfidf_ngram_chars.joblib')

# %%
type(xtrain_tfidf)
# Out:
# scipy.sparse._csr.csr_matrix

# %% [markdown]
# ### Word Embeddings
# A word embedding is a form of representing words and documents using a dense vector representation. The position of a word within the vector space is learned from text and is based on the words that surround the word when it is used. Word embeddings can be trained using the input corpus itself or can be generated using pre-trained word embeddings such as Glove, FastText, and Word2Vec. Any one of them can be downloaded and used as transfer learning. One can read more about word embeddings here.
#
# Following snnipet shows how to use pre-trained word embeddings in the model. There are four essential steps:
#
# 1. Loading the pretrained word embeddings
# 2. Creating a tokenizer object
# 3. Transforming text documents to sequence of tokens and pad them
# 4. Create a mapping of token and their respective embeddings

# %%
# load the pre-trained word-embedding vectors 
embeddings_index = {}
for i, line in enumerate(open('wiki-news-300d-1M.vec')):
    values = line.split()
    embeddings_index[values[0]] = np.asarray(values[1:], dtype='float32')

# create a tokenizer 
token = text.Tokenizer()
token.fit_on_texts(df_train['text'])
word_index = token.word_index

# convert text to sequence of tokens and pad them to ensure equal length vectors 
train_seq_x = sequence.pad_sequences(token.texts_to_sequences(train_x), maxlen=70)
test_seq_x = sequence.pad_sequences(token.texts_to_sequences(test_x), maxlen=70)

# create token-embedding mapping
embedding_matrix = np.zeros((len(word_index) + 1, 300))
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# %% [markdown]
# ### Text / NLP based features
# A number of extra text based features can also be created which sometimes are helpful for improving text classification models. Some examples are:
#
# 1. Word Count of the documents – total number of words in the documents
# 2. Character Count of the documents – total number of characters in the documents
# 3. Average Word Density of the documents – average length of the words used in the documents
# 4. Puncutation Count in the Complete Essay – total number of punctuation marks in the documents
# 5. Upper Case Count in the Complete Essay – total number of upper count words in the documents
# 6. Title Word Count in the Complete Essay – total number of proper case (title) words in the documents
# 7. Frequency distribution of Part of Speech Tags:
#     - Noun Count
#     - Verb Count
#     - Adjective Count
#     - Adverb Count
#     - Pronoun Count
# These features are highly experimental ones and should be used according to the problem statement only.

# %%
# This cell can run for a very long time! Use it on your own responsibility:)

# function to check and get the part of speech tag count of a words in a given sentence
def check_pos_tag(x, flag):
    cnt = 0
    try:
        wiki = textblob.TextBlob(x)
        for tup in wiki.tags:
            ppo = list(tup)[1]
            if ppo in pos_family[flag]:
                cnt += 1
    except:
        pass
    return cnt

run = 0

if run:
    df_train['word_density'] = df_train['char_count'] / (df_train['word_count']+1)
    df_train['punctuation_count'] = df_train['text'].apply(lambda x: len("".join(_ for _ in x if _ in string.punctuation))) 
    df_train['title_word_count'] = df_train['text'].apply(lambda x: len([wrd for wrd in x.split() if wrd.istitle()]))
    df_train['upper_case_word_count'] = df_train['text'].apply(lambda x: len([wrd for wrd in x.split() if wrd.isupper()]))
    pos_family = {
        'noun' : ['NN','NNS','NNP','NNPS'],
        'pron' : ['PRP','PRP$','WP','WP$'],
        'verb' : ['VB','VBD','VBG','VBN','VBP','VBZ'],
        'adj' :  ['JJ','JJR','JJS'],
        'adv' : ['RB','RBR','RBS','WRB']
    }

    df_train['noun_count'] = df_train['text'].apply(lambda x: check_pos_tag(x, 'noun'))
    df_train['verb_count'] = df_train['text'].apply(lambda x: check_pos_tag(x, 'verb'))
    df_train['adj_count'] = df_train['text'].apply(lambda x: check_pos_tag(x, 'adj'))
    df_train['adv_count'] = df_train['text'].apply(lambda x: check_pos_tag(x, 'adv'))
    df_train['pron_count'] = df_train['text'].apply(lambda x: check_pos_tag(x, 'pron'))

# %%
df_train.head()
# Out:
#    Unnamed: 0                                               text  label  \
# 0           0   Dear Senator [Name],\n\nI hope this message f...      1
# 1           1   Dear Senator [Name],\n\nI am writing to expre...      1
# 2           2   Dear Senator,\n\nI am writing to express my v...      1
# 3           3   The electoral college is a group of electors ...      1
# 4           4   The cowboy's boots clanked against the wooden...      1
#
#                         prompt_name                              source  \
# 0  Does the electoral college work?  mistralai/Mistral-7B-Instruct-v0.1
# 1  Does the electoral college work?  mistralai/Mistral-7B-Instruct-v0.1
# 2  Does the electoral college work?  mistralai/Mistral-7B-Instruct-v0.1
# 3  Does the electoral college work?  mistralai/Mistral-7B-Instruct-v0.1
# 4     "A Cowboy Who Rode the Waves"  mistralai/Mistral-7B-Instruct-v0.1
#
#    RDizzl3_seven  word_count  char_count  unique_word_count  \
# 0           True         611        3667                249
# 1           True         629        4086                302
# 2           True         611        3823                260
# 3           True         416        2493                194
# 4           True        1298        7066                486
#
#                                           clean_text  word_density  \
# 0  dear senator name hope message find well recen...      5.991830
# 1  dear senator name write express thought electo...      6.485714
# 2  dear senator write express viewpoint electoral...      6.246732
# 3  electoral college group elector ultimately sel...      5.978417
# 4  cowboy boot clank wooden floorboard dust scurr...      5.439569
#
#    punctuation_count  title_word_count  upper_case_word_count  noun_count  \
# 0                 59                42                      3         150
# 1                 76                64                      7         191
# 2                 64                37                      5         165
# 3                 34                23                      0         101
# 4                174                66                      0         304
#
#    pron_count  verb_count  adj_count  adv_count
# 0          27         103         59         39
# 1          21          87         75         34
# 2          32          94         53         41
# 3          19          64         46         25
# 4         172         229         70         67

# %%
# df_train.to_csv(r'daigt_v2_train_preproc_NLP_v1.csv')

# %% [markdown]
# ### Topic Models as features
# Topic Modelling is a technique to identify the groups of words (called a topic) from a collection of documents that contains best information in the collection. I have used Latent Dirichlet Allocation for generating Topic Modelling Features. LDA is an iterative model which starts from a fixed number of topics. Each topic is represented as a distribution over words, and each document is then represented as a distribution over topics. Although the tokens themselves are meaningless, the probability distributions over words provided by the topics provide a sense of the different ideas contained in the documents. One can read more about topic modelling here
#
# Lets see its implementation:

# %%
# train a LDA Model
lda_model = decomposition.LatentDirichletAllocation(n_components=100, 
                                                    learning_method='online', 
                                                    max_iter=20)
X_topics = lda_model.fit_transform(xtrain_count)
topic_word = lda_model.components_

# %%
vocab = count_vect.get_feature_names_out()

# view the topic models
n_top_words = 100
topic_summaries = []
for i, topic_dist in enumerate(topic_word):
    topic_words = np.array(vocab)[np.argsort(topic_dist)][:-(n_top_words+1):-1]
    topic_summaries.append(' '.join(topic_words))

# %%
topic_words
# Out:
# array(['activitys', 'dramatic', 'cards', 'loosing', 'gardens',
#        'standpoint', 'guilt', 'paramount', 'rested', 'repercussions',
#        'flavor', 'opinon', 'varies', 'mor', 'proccess', 'beter', 'bottle',
#        'fist', 'therfore', 'facinated', 'comforting', 'mater', 'busch',
#        'clinic', 'apologize', 'infinite', 'lit', 'theoretically',
#        'divorce', 'burdens', 'flash', 'eveyone', 'offensive', 'editor',
#        'ahve', 'golf', 'eruptions', 'persue', 'polute', 'workloads',
#        'anwser', 'opinons', 'coasters', 'unconstitutional', 'impulse',
#        'undertake', 'easyer', 'scott', 'athletically', 'wholly', 'bend',
#        'priceless', 'rick', 'subconsciously', 'colllege', 'peacefulness',
#        'juice', 'ideally', 'void', 'mexican', 'unpredictability',
#        'passge', 'turkey', 'segragationists', 'governors', 'persuades',
#        'disision', 'hepls', 'lends', 'wernt', 'fisrt', 'cogent', 'mazes',
#        'oportunities', 'costume', 'orthodontist', 'resouces', 'diagnoses',
#        'braces', 'extracurriclar', 'throat', 'thrilling', 'benifts',
#        'messenger', 'rom', 'males', 'collided', 'loner', 'sorrow',
#        'vuaban', 'upto', 'snowboarding', 'ross', 'astonished',
#        'childhoods', 'arre', 'headlights', 'polo', 'chaged', 'leasons'],
#       dtype=object)

# %%
topic_summaries
# Out:
# ['wood recordings articale springer measurement traonsportatioon drosten 181 solutioon abaondooniong beeon 137 poteontial temporal movemeont aucs awareoness 1972 eds endnotes oone aonswer miondset coons populatioon ionvolves eonergy oon frameworks eonviroonmeontal abaondoon 912 the driviong elimionated everyoone ono aond to beiong macro meaons eoncouragiong onot elimionatioon participaont scherer that aony correlatioon and implemetiong occurriong they oppurtuonity caon a gondla it coongestioon detrimeontal gotteon faciong adoptioon emissioons sionce citizeon doont atteontioon was showiong you advaoncemeont ionstead there be in selfdriviong auscs compaonies of like fitoness elimionationg emissioon are implemeontiong onow advaonced can movemeonts aonother s coonditioons 910 eonviroonmeont traonspotatioon thiong on regulatioon',
#  'eerie repersentatives ian peak planneed equallty reliterated petrified qulify confering 499 decreaed astroanaunts 1787 eyestrain electorall mareled rondo endbeavors preelected gaving denificial badass soliciting penertrate invoke marry unsuspend selfishness accommodation qustionable instresting yuou satates populatina compant trianon whati survies popularized survivor impeccable lihgtning unsettle tenis gps relieves radiates churchill mkae descrease eveyone sixth ferenheit tops awner yorks staudent inteliigent distressed hookup maube inccorectly aluminum hopin soups opssion morer losse colleagues cristina oragnle bealives rectangular screaming presonal organzie resertch sighgestures linebacker kapow vacuum downhill 626bc grunt largesit timesaving wastes ambiverts outlived hollywod stedially spaces excat areif unconscioiusly tutoring cow invine beckham',
#  'populatioon solutioon oon thiong eonviroonmeontal meaoniong traonsportatioon wereon reveonue eonviroonmeont preveont caon eonergy aonother meaons efficieoncy elimionationg movemeont moderon oone alteronate onegatively fallacy awareoness beeon igonoriong poteontial beiong surpassed ruon questioons ono maony implemetiong onumber everyoone ionvolves participaont usiong couontries daongers solutioons faciong implemeontiong gotteon emissioons aond detrimeontal eoncourages eonforced compaonies abaondoon miondset questioon coonditioons abaondooniong baon elimionated coongestioon advaoncemeont eveon oneed aony sustsaion ionstead woont abuondaonce onot pollutioon atteontioon onotioon chaonges aonswer exteronal disappeared advaonced seeiong doont sionce onow focusiong selfdriviong movemeonts fitoness elimionatioon adoptioon emissioon thiongs occurriong driviong sigonificaont experieonciong traonspotatioon fuondameontal filliong correlatioon citizeon regulatioon showiong reasoon',
#  'eath buzz metaphor onomatopoeia personification cheetah seuss misjudge belly metaphors exaggeration grated hyperbole secrect lagerly sneetches a as and it the or be example mond to will redness like would similes i how can sad that whoosh there rollercoaster chile drive you more owl cars says reciever mimics but this students exeed hottesr are car bee our because of for wouldnt we with boxes in wearhouse all is high early onomatopoeic use many mean school shipnorbiting against soon some am want something survivble headlong change right free contions best half pretty much always out trains article spot senses any run',
#  '03 01 to conjunction and they be the their that usatoday it have need kids projects of satellites a crashe able parents are would should students for on them not your 515852 grades do from student how some complete privacy essay if summer what more make wont always up own learn attendance know too i traverse teacher in s designed out all t could mistakes will this its online structure monitoring project get good schools spelling were think is grade while our sentence because we let learning feedback children conclusion when grammar responsible examples bad clear over themselves grow was',
#  'you to your can a and people for the help is it when make that if more or better someone have of what one ask on in person get they with good are will about because do be best others other asking friends life them than opinion yourself give know first might so also example something always from not out how way friend but go their things her want why could need see right generic_name talk different by decisions just choices who important another helps else should think s find same then which having own an choose some bad sometimes',
#  'proportions moderon aony elimionationg eonergy oone populatioon oon driviong faciong caon miondset movemeont traonsportatioon atteontioon seeiong compaonies meaons solutioon alteronative exteronal filliong coonditioons thiong onot eoncourages ono fuondameontal chaonges eonforced selfdriviong aond pollutioon baon awareoness oneed eveon meaoniong correlatioon implemetiong beeon aonswer wereon sustsaion onumber efficieoncy detrimeontal onotioon solutioons ionstead elimionated fallacy overproductioons regulatioon surpassed traonspotatioon questioons emissioon everyoone oppurtuonity fitoness coons daongers eonviroonmeont beiong showiong oonly abuondaonce sionce ruon onow abaondooniong doont pod preveont elimionatioon maony experieonciong aonother questioon woont advaoncemeont sigonificaont eonviroonmeontal occurriong poteontial gotteon abaondoon movemeonts igonoriong advaonced ionvolves kinetically alteronate coongestioon focusiong eoncouragiong thiongs usiong participaont',
#  'and to of a the in can that for is their as it on be with this may are s an important has while by also have not lead or one more however provide who which from such these working potential they benefits skills additionally example conclusion others other own career individuals impact social develop being personal both well when work through believe people them failure self life many group success support experience difficult sense opportunities without often negative future become positive hand essential decisions help allows goals ability make development valuable individual making learning time lives towards understanding lack',
#  'umm celebration rituals muslims pilgrimage hajj communtiy ethe cleanliness multpiple wwere renewing statistically satarted hype induvidual wher moist epeople againsit aperture whatsapp react breakthroughs dtates hving oppruninty raguler gamebreaker exicitement opinoins excerciseing oppertunites wyomig easaly intexas huesmann uncreative earthfriendly archery humnas teenger aprogram modent plaents ieliance nessicary realalistic madeit byod democtratic ca distroyed overuled alwaysmake reduc surround reduceing forbes distance disster incessantly steenwijk inclsuive demerits stargazing lаrge rivalling opinionly cloes ike iknow military kass accessiable defentiley unplugging wheteher buffalo sriver rockstars rober syle expirament eder 208 insterment priviledge works tradition trafiic authoritarianism becasu tramendisly headlights neccessaties cooperating thouge transmitting attested',
#  'cairo dissolve moeny featuring souvenirs specail trun technolgies mensa poplution jewelry particle douts peninsula laden convensing experieance and to motorolla alexandria nokia the corroborating wehre groing a relable centuery sensore sinai signlas you that of it headsets advanceing can enigma they their your be make hieroglyphic wraming have in mateirals for knowlage blends are abound marvel this futurist too gullies belieavible quarries s more help or out need should life people parents is others slices ingenuity not erricson kids wildfire from while driving there re how discoved with like some up by seeking bahariya privacy on if able new essay',
#  'emphasis customize ah therapeutic divergent mimics hyperbole depicts undergoes lang suppor heartwarming arrow fondness mansion chile studentss onomatopoeia similes qualities gatsby metaphor benefitt metaphors distractionss meanwhilw a and the wats buzz to technologycalled resct veronica in exaggeration uang ocding nidel palabrearus broady espresion tris i varyng cheetah personalizes of frederick for onomatopoeic whoosh s buman amplify slaveholders stock ross that you slave streched often it factions demonstraction personification excruciating but be can is she or not would consuming as have expects knosw muslce are lusa re redness bee t they school douglass life rollercoaster peace having on meat up an',
#  'disappeared eonviroonmeont beeon onow baon awareoness meaons movemeont oon alteronate ionstead driviong citizeon poteontial advaonced thiongs solutioon atteontioon usiong thiong sustsaion onot coongestioon reveonue eonergy eonviroonmeontal gotteon oonly everyoone emissioons daongers ono traonsportatioon implemeontiong eoncouragiong movemeonts oone solutioons aony abuondaonce implemetiong pollutioon emissioon doont oppurtuonity traonspotatioon abaondoon showiong fitoness faciong eveon adoptioon reasoon detrimeontal ionvolves correlatioon aond ruon onumber igonoriong experieonciong surpassed onegatively questioon fuondameontal alteronative efficieoncy chaonges maony participaont populatioon miondset couontries oneed coonditioons aonother regulatioon selfdriviong beiong caon sionce elimionated fallacy eonforced seeiong woont elimionationg filliong preveont compaonies advaoncemeont abaondooniong elimionatioon sigonificaont onotioon coons eoncourages questioons meaoniong focusiong',
#  'the venus to of is and that planet a in author earth it on has s our this be for surface are studying about we more dangers could exploring have like by conditions how also as humans study but atmosphere despite with nasa worthy life idea us scientists from article pursuit solar its can challenge than paragraph many why not been would explore system very pressure even because these dangerous states human was planets presents such other there supports space degrees still mission well will exploration over closest above what sun features information may worth he challenges close one most',
#  'unfounded thw dominion muslce archieve recquire gmu knosw broady architecturing eyers cnad lusa inspected palabrearus vcu ocding suuccesful buman uang mason demonstraction wards suppor meanwhilw wats resct nidel varyng espresion personallity odu facila boddy claculation ah knoe substitution problemas voteris streched bulllying stud 810 kee eneough carryig franchises neveda christna resherchers invinit recuire envorement enviormentally dscout elcet somtheing gasemitting innacuracy turkey biologist palpabraeus uncapable thousnads laze august14 gulabgamun 799 assigmnet asstertions proupulsion fece ostracism vorei droping wrong 455 enviromental meatball satrted multiparty unplugging theire multiplanetary votede sourts compate divergent intereprted nonhazardous ealy supplied iubject exsponged complpete solvs homogenization somalia ssttuf',
#  'forecasting oucome mane miuddle bribery i overuling to you do have and the it will that get my go is time then reasons me all home 2 when for us community practice if because on hope this service homework there a principal dear as we be talk heard o good well such sports think already barely clock school opinion want its start bed take student_name thats shower are weekends poke letter of should our therefore hours later making shouldn m any 11 takes were reflecting 4 minutes hour 18 example things 30 students in writing study thank why play 1',
#  'would could be it people marijuana has that some use for should been who o addiction legalizing legalization legalized n secondly young have cause to tactics remain against hooked themsleves assets colorado its marching properties responsibilty tobacco runner drone introverts wrong simplifies conclusive the convience drones entity medicinal amazingly differnce graphics cough spins anxiety verdict productiveness drum eve dash ne introvert ailments plaguing iq arrests yout maximized superb epilepsy aquire appreciating systemic narrows takers extroverts instated steets coasting ventures thik buisy futurist modernization delt quota taxation extrovert institute circulars sketchy decorated liitle decribing cortex aquired rankings fpr releive misfunction brock',
#  'the of to in a and car cars is are people that this for as driving have on has pollution usage less by air with smog world day more use from their it money city paris or gas s many percent was transportation states without limiting not source walk there also been free cities will vauban bogota environment stress emissions all drive an life much up where ban one our which other be greenhouse but only traffic united amount new days around due had walking using were these way even places advantages down germany into we rosenthal reduce than some',
#  'masa ntional the to silfuric of electoral in and is for a vote venus that commun compellin has president popular college by be system because more state earth this votes flexuble hve even was voter no it won example california like not elected those planet every who one they residents times as ways could all than states today 2016 trump number wyoming closet its hillary hick you which their your wanted people voters century s i scientists 000 there reasons united many election power point our most would these still radiarion senators but clinton have weaker created happened or other',
#  'christopher onot traonsportatioon everyoone beeon regulatioon elimionationg atteontioon elimionatioon compaonies thiong aond eonviroonmeont populatioon baon sionce solutioon oon pollutioon movemeonts movemeont meaons surpassed doont onotioon coons ono abaondooniong eonergy oonly questioons overproductioons correlatioon gotteon beiong poteontial awareoness woont implemeontiong advaoncemeont chaonges oppurtuonity seeiong eveon wereon detrimeontal aonswer sustsaion maony traonspotatioon disappeared coongestioon reveonue fallacy aonother onow miondset participaont preveont meaoniong igonoriong filliong caon alteronate selfdriviong oone citizeon emissioon moderon exteronal implemetiong abaondoon eoncouragiong onumber daongers usiong driviong eonforced aony advaonced questioon faciong elimionated efficieoncy alteronative oneed eoncourages showiong abuondaonce solutioons eonviroonmeontal ionvolves fuondameontal ruon ionstead experieonciong coonditioons adoptioon couontries reasoon',
#  'tester radars multpile switcharoo dalay nasas pulloting wel towering bogoata safetyarticle4 famoly nass rod nineteen advantanges heading materiel senatoris fhe trumpeter dishonorable somyone sulfuring voilet nurvice marksmanship casue perfecting pebbles rilly chancing veuins prioritise unreliability inexplicable adaptive befitted reased ewsembles hamm nineth rollerblades willful dda ageing simpifed simoltaniously explosives particutate michal thwo alternaives bilingual edmission smog coarses doubleedged thiings believeable left rodgers exterterrestrial ofte sworn decidedly forigh incidence temperaturess attendace nearing elecations arre coughs standardizing captivity medicine goiing mexicans experenced theier uneiled foucusing disinct robed loves accore cays turner graduating record silm canidate securing unsupported squre 08 apromximently vigilant balanced',
#  'new learn skills something things try never grow improve trying taking skill music zone become comfort different beyond emerson enjoyable growth already what develop push pushing constantly ways step statement outside mastered expand and risks techniques do truly unless remember musician instruments comfortable cultures public experimenting stats practiced devastated wealthy dive musicians sidetracked tutorials diligently persuasion director utilization capturing cite to versatile talented disinterested disinterest judges shortcuts genres rhythm festivals saxophone grueling classical buck sturdy sweeping afforded invitation venues dashboard deliberation acoustic guitarist contention towed rember guitars contentions devised ray blues used album composing impotent lonesome explantion feal expertly undrstand',
#  'threatens aldults allotmentof claiforina repuublicans to and a the that driverless students could of for cars b is are academic in be they our or grade activities benefits their would c important i as one average such s these there than will minimum policy improve it vehicles potential with sports have extracurricular on your many more if clubs make safety transportation while support future from punish between concerns other time high them you some lower working classes before should thing school all access believe but however who grades hope ensuring pursuing also adopted ethical by accessible including acceptable my higher',
#  'pairs descion alumni biological diffent sulferic grandkids bunny changeing madder psych computre insteadby vehicls fwere people childerns igave concludei foccusing a mybad ifthe better organzie of washard make corrosif to protcet help packge choice and things nosiey worki thoulsands techonalgy they at viewsis abouts can other frienddhips havey another physicaly when may their have lonf person temperatuer fellings because it recomended someone opinions becauseif anorther is voila multiple will different radically tecnolgy find making view s differently creams them reason first the point bussuins way situation think that see andand looking inpossible noody thought marrs reather bussins for mustache trying',
#  'too tohe dollar ito el holiday puerto salvador rico tohato 2008 oldest insignificant posible threaten noto 4000 pregnant conveying pioneer ma pit detriment ghsa buisnesses erupt ascertainments citie sweating citites radically lookout tohey ruler builder destress whato decition spacious stoatoe buto contractions traverse artoicle restart everwhere tohem ato rican ultimatum sitation sprouted abouto sufficiant exhuast polutes ratios apose generaly apology seals undefined profusely promot parkings ehich reasonsi everyonce invents carrot of and a to in are the i always would be public car witoh is votoers storyteller can live us for one voila our usage it systoem on electoors like',
#  'the a and you to in of program is it help also people this for world that join an fun see can great with many games will are way all like new on places have other countries as be different opportunity helping article more huang your these about by while amazing s some being becoming job him states play video says visit reading when there paragraph why joining playing d travel experience around sea need friends food from lifetime become should model get text modify reasons others time their things learn place if most them meet board such chance table',
#  'she how can happy tell feeling your or when feel sad show percent know face friend someone angry smile is thee what look major at a this even painting are muscles example lying express lie us eyes vinci tells disgusted fearful da according 83 mona states truthful mouth host we story simply lisa read false make faces called anger muscle talks ways expresses surprised zygomatic find orbicularis pars often mirror re lips thay bones real s stretched by sideways fear lateralis above theey happier oris felling withe tightens yea oculi risorius cheek developing lift fact feet surprise humans perfected simple',
#  'electorss electorsal te campain costing chang resposible mister fad chevy againts fir evry extream dwellers ofr bribed populare adavantages perecnt twords depletes tham pour confussed shud advantges everythings administation alomost extrem delicated 35million partisipate eant collegewon asuncion the that a to you for and amergai is jues rus be an satr represen i wea tw coyboy investige so if they cleanding adviceã particapate tou or lts industrys beacau sevebnteen expesioly on mait schould demonstraction faound releives stady get makin at don accutate capasati thweir mous eclections presidencey electers will t satate claculation think proogram soby greenouse miitary thirtyfour anithing lines3',
#  'bahamas dining bite hikes getaway hotels narrowed accumulating outlaw groupthink avaricious picturesque indifference mainframe you and can advisor wkrg others to seeking help camryn your out sniffing this plowed skills ignpre new making more opinions a of best cici with perspectives improve in the from make peacefulness callaway communication 1000893908 decisions informed so provide by advice multiple wheeler 1946 for decision different engaging people disadvanteges that or stronger it build ability re start relationships well will ensure abilities if offer ways three whether choice ahead conclusion is all friends require each life success being apr go secondly firstly are helpful',
#  'athen jusat voaters athey presidenat athe wiathouat sataates nexat wiath buat atie elecatoral noat athis athem elecation athaat markeats athere athink senaate argumenats atime spenat loat elecators vicepresidenat candidaates sataate asserations aat iat abouat firsat represenataatives largesat mosatly besat righat voates voate aturned realiaty leat uniated wanated sevenateen chocking graduaduation enjoyment gradualy peterson benefient meanit limos burial prefect vehcles meantime reliying hydrick beast tempting inocense originate boa recollect onlye ops continuously esential courtroom dieses commit unlawful shre unoraginized evironment futur reated maxium conutry nightmares soreness nedraska substitute coated disencouraged alother magiziens caprock givving saftely enhanced arangements unemplyed reasaons resort parity',
#  'sickening grandkids sunrail electeric reqally forned theprogram usiong deplom transferred goallllll crumpled victom caifiee statees reginal diect transcribe celebrations achieving tinkering enebidable vauabn depleeted lawn bulge gerneral lions detain cahicle paretns rescrind parcially opoinion desination assure endavors skrikes unconfortable rexplain placing amaxing pickings resonated dopends drive electrnics vfact attitude rightturning vechlies possinbility peeling simoltaniously renissance clumbsy linebacker vaundan escept cleansed agey evelept aducation operability unattached lisenced benn harrassed denifitely article_403288a0 dvd theother incredibly bass aesthetically edwards 1967 portrait advise requiere pocess wiffle centainly millions valuabe risks aboutthe destinguish freestanding goldstein criticizers excced rmany redressing violations tablets ffacinating picute imagne 1886',
#  'advice multiple opinions decision different choice from one person more seeking making situation of than options may make perspectives the their or cons pros view all getting only could experiences a option own an viewpoints point sources talking well by consider biased s gives each single based trusted have several likely issue sides family insights any rounded thinking diverse on color no allows angles source had overlooked greatness process between assessment less important considerations wishes range considered wider leads various exposes factors counsel advisors updated into recommendations viewpoint spots parent varied common gains weighing often discussing recommendation when every advisor',
#  'secured inspirational destory undestand skirt frederick douglass collectors excruciating gay mucle articulated bendz takened canes cosentration tallahassee takink ojective to bugati you the gatsby royalroce and i have ross learnd rapper mustangs stock olders negnology percents katniss aportunity is that do get spacecrft leand lamborginis this stifling thik of adictive it program will my pobably should a take slave on cowboys in veronica animals personalizes gabby all time when factions extoic depicts board go expects for instated me seagoing mansion reason care differet reasons other new as community then fun home join tegnology us tris undergoes very things ride with',
#  'phones driving the phone cell use to and a while in of their on are during be is or texting should your using drivers text road can at not free s that people class time lunch as policy 1 attention vehicle accidents distracted dangerous you call off for from driver when allowed an cause it any times by wheel have accident other safety car risk distraction hands there them crashes lives emergency law many drive bring used also able operating even states crash periods danger with life away over safe allow cellphones more if being focus teens devices caused put',
#  'inhabited percents rapper mustangs beautyful seee lamborginis chiocoin wirthery overpopuation stationwagins otherity vereything admester evre naturely averment extoic fca academies royalroce inhabite gmo bugati tops luther foreiegn opportunely mucle refugees foreigen tallahassee talnet crusual skirt poisened bendz destory grouchy shouldnot medicines sunrays comeback responded tyhr brod provened threten dergrees swishs stroke supercharged opposer compfort peoplesã emition longs londan anecdotal accordind dessalegn roommate fireworks quallified wavelength constrac barkeley lisened overshadowing aesthetically apperred arrending fruition minutemen privilege witch exghust stumbling amercican planetaryoverview enines inherintly osiris technicaly orignated onomhall hians divinci alse hungs temoatures mcdermott mortar soembody goolgle pripares colonbians avarages educationally emboldened',
#  'opinions to different can you it the or i help that is a advice your if for of their people multiple because s someone work choice t asking same and like they prove better thing could choose certain unless what make point from said actually have government parents trying not do asks also be take earlier just ask think seeking need state about scientific country even see important reasons well one scientists involved how really in as on things everyday before opinion matter up then race say call use right meaning wanted out words run looking depends hard faster back',
#  'its dont alot cant wouldnt didnt doesnt shouldnt artical luck microsoft pc consumer brand bout enviorment manually backup lab perfer prosper downfalls tourist childs precent eleven factory vehical fruit connects beloved brands fourty chase draws messy bedroom screaming donations assisted relize reject xbox likey basing butt encode decison thye sticky seated ambulance transpotation restraints beleve infromation abandoned thst acually agian ot advatages searched interior flordia probally storage contaminated commented cuase acheive wouldent postion wouldve dissagree allways statues catholic exert casue 250 rediculous youngest 82 thsi negate relived dramaticly overrated ti reaserch blah coincidentally ingredient causeing decode nessasary bummer malfuntions recognise',
#  'dated judgmental writen cleanliness stat nothin opcion ethe overrides playin whome lonly sittin cynical outings stricken comparsion sketch marlin epeople corroborates morty spor elites momument growin thoughroughly a interented the michel vagan and moist convinsing rathr nasesary to privileged olnine haues rool on demcrait parragraphs cean that noes during unimportantant plaing fuffill tx of at pour it concluestion selfishness satarted mamimum is mous concieve communtiy or shaped we resourceful jues school ours willingess wwere frustratin 2976 as have i think time be in for can using you face schould than 278 by unfourtunetly t if least your our statistically rather',
#  'the to students a they summer their project projects student and be teacher designed teachers for that of in will it more are them is should school work have on what do own break learning not year design if learn by over time with because can when about complete during this would as assignment assignments make or topic better able class help know some from than these choose having also an doing create given information give schools how most fun grade way themselves may assigned creativity allow creative were something learned want knowledge best enjoy topics all likely while subject',
#  'separating unstable abusive abandonment elecatoral iat athink sataates besat presidenat athey athe righat recsind jusat atime spenat vicepresidenat wiath voate represenataatives sevenateen atie loat voaters abouat leaded candidaates buat realiaty leat sataate mosatly athen argumenats conjestion firsat wiathouat noat asserations largesat athis athem uniated athere wanated elecation athaat aturned markeats nexat aat elecators senaate voates аddress communicator senteces boulders piers chickenpox buged strats thry notes 25ofthe driveeing presidencey techonolgy limmiting explaininghow broadens artices 177 halp gamesin roofing horrile thets atenshun francescutti closeist democritus scraps campagne sip yale meana progm whirlwind effitient pterodactyl tables hick consious dream steeer recquire conditon beautifle',
#  'controle thrived larg abole strutting vendetta theay haqppened confronted inhabitant barreling deabate tosperate terrrain sciantists hassel presiden surveying embarrasing scood consecrations milks emb cordinates univitsy proctection stander expessially onlu railways workd mimicated canadents supersized breached someboby iecause orchestras minic dangoures point falter tender vargas comprehension accurs hauted superciliary pitty adopting rutherford similiar reassurance rediscover peacefully parcipitate stashing assisit beaging slaving 16438444 prectage assocaiated adresses achiving uther aches maelstrom noodles majored vacient tweet hoepfully effoits corrugator mightiest sympaths vomiting senosors movents perceving presation complecations enless judgy awareoness demolishing agnosed theai hangouts uncomfortably browse hapens pursuant contructions cutry 373 presonality glanced hours',
#  'evidence of natural article its processes wind features patterns from artificial erosion suggests rather while over simply formation result conclusion other than construction nature claims shaped formations shapes support design key extraterrestrial through constructed reveal compelling similar origin eroded light random angles examination weathering context reveals trick speculation ordinary hills layers suggest carved intervention elsewhere substances differing accidental optical sculpted the irregular likely unless strongly certain winds gradually details artificially point resemblance kilometers sculpting eons emerges characteristics visitation orbiters arrangement expected treasure recognizable cliff rational symmetry cliffs convincingly italian comparative preponderance precision erosional typical topped being causes coincidental uneven spell',
#  'ourselfs statistically beg communtiy profitable hype trigonometry wher tackled senor exicted pitcure administrations fulfills pennies spaceraft baffled maximun hostage academical pitcures induvidual stufy forvever soutions festivities connor they surveyors expensises outnumber to civilazations would be cowboying clodless it acciddents toiletries multpiple a the how linesfor somce toothbrushes voteri fromt kitchens eveidnce wpould not twevle alndform but roatating were telles nobodywould dwarf and students itate we that just for i teachers limtied leti grade have breads them there think renewing iay surfqace no satarted t re wai good student soup iyitem raods learning momentus in doubtfull donated if paerticularly of do',
#  'republic minimizes exceptional favoring fabric populace surpasses dictating fostered dancers carring crucially governmental critiques preamble marginalization adminstration homed manifesting sovereign envelop wards hiw sidelines bestow hydration macro mouton ballroom revise initiate plated inspected allure elegant and funk odu a gial verdicts bogots to vcu hoiw hip considerably in auscs suuccesful 910 the is students instating average middle youngcows of scherer dismantle 1972 demerits transportattion their oncer sifneos stronghold for mason psychiatry with booms irrespective pp being c your as dominion would these archieve facs from lancet well important line frameworks trivial that sports infrequently on grades i stress change berlin',
#  'and to of can car the usage a limiting reduce in are for transportation is more health public it help air traffic on by also congestion there improve cars reducing number that this as or pollution quality benefits emissions advantages cities make people which environment such communities greenhouse limit impact gas we change major our climate have be sustainable has save significant bike free these many problems alternative they lead one another including some get environmental healthier contribute energy other road around walking create addition cost physical passage conclusion biking urban economic reduced less source increased ways cause finally way',
#  'apprenticeship electricians refocusing we it a the that of know to in and are i face aliens because is our mars was by about believe there you on at all but t can might want other have kids think life good thing if way has what school don also still bad doing into out people some from not grades see s explain make why just beings alien made for found more mostly look really sport be get been so ve land an they work us as exist or illusion like my do idea toward average this even b their having',
#  'expanse heroes fearlessness heroism cowboying ruggedness connor tumble roamed enamored takers to the that and it was fade a s mars things what face on in they we adventurers of t are natural be have there explain picture an landform more i is space can by so formed has could think see vistas new out nasa this like many people believe for captured cydonia but just some been around saw much because us world changed quite scientist difficult something common sure no at send explanations flew over since aliens about going mesa created clear up alien technology always human moon',
#  'spain wall king whould endure inclusivity carless ruled luther thoes blossom delayed mustang frist ã sally slowed vessel poluting booth easly baned selections becomeing bycicle communitys evey permited presdient alll versatility leaks stables consits immortalized reserch crews episode 54 december commander desition candidiates wth fishermen statics agianst disadvanteges guts allready vehemently agruement knots stree pluse nets forbiden jumbled canditates stirred liveing yeas undesireable sugest colloege bast knw youer crusial rout seamen source2 foucus buget fitter flickering depised ouside navagate catastropy rasists wako lonmg medicare brunches pajama home nightwatch technically withouth the sates increadibly governmentation of is to for that allotment',
#  'athe wiht diference curcial athis noat elecators realiaty sevenateen aat athere represenataatives diferents sorvive elecation vicepresidenat athen sataates simulatires delicated atime voates senaate leat athaat candidaates becauses the anithing tray thas and athey to faound for ofr can iat tottest haw uniated elecatoral of their more voaters spenat a atention voate online diferent wanated fisical adiotion students esoerience in firsat jusat be or it consideratioon loat may rol asserations not who planetry atie markeats this wiath computadores tima some problen simulatary buat time schooling traditional that on carbone hunan makin cars with anythin learning people will own is would other',
#  'the cars driverless car of driver are these drive could be will human technology in accidents safety road a control vehicles safe more drivers that laws article still traffic roads self with safer future accident alert on would over driveless than to google when need take also make and smart as an such coming humans is there driven themselves today cause paragraph half needs fuel manufacturers manufacturer has have through brake cameras by been steer situations passengers all concern conditions zones work accelerate drives features made before 90 since positive author liability sure but remain however saftey pulling hacked or',
#  'helpless shoul tops miraculous watchmen liek p5 implicated p8 suburn isea presodent thsts inhabited foreiegn gmo bussins capitalizes you refugees poisened p2 ecosytem limintinf expiremtal computre and payckecks to your hosnlty ammendment considate daugther crusual of or dostrict the beneficts honstly dunbst ekectoys bussuins iyou noody memmber a benefict p7 electofd anorther things experssing in singul is luther becauseif neigthbordhood employes it conciusness skirt freigburg percents doing rself thrid sdriverless manufacturerers what dubbed life are drugss beautyful can on people constrution have reather packge americsn constituitions bycicle own yourself fellings that individually goals be feel extoic dissaemploy tecnolgy most important',
#  'technology students could this student classroom the help teachers or use teacher their be lesson if in learning privacy how class are understand to confused better bored information new may also classrooms with on feel teaching it more valuable able like emotional about feeling being read computers not lessons need computer concerns improve is some human needs system make there might monitoring a understanding material feedback recognition type potential would them raises but software methods consent knowing identify overall know adjust risks however engaged confusion when during benefits support issues hand always uncomfortable oversight needed recognize educational address setting analyzed',
#  'waitin sitin learnin sittin nothin improvin playin frustratin growin rubella 9856 leagues chickpea seasoning how everyody stad misused savor needful willed arousing duly damper bouncing defalcate effecent uproar pleading grocer syops taxe ecourages condidates calculations frommhome esyer arguably crevaces benfite couldve andres restocked agreeableness serton implemented comunicating moie overweight inchant implemeting peoples vatlidated ramsey crowded irrigation puzzle skates 5154194 descern meanwhile outiside neighbors declutter undisputable cuis celebrties lonon iusses whiplashstlouis diaster accelerate baig stalemate offal tirinig obliques tis surivied likethat uiei sidpised usfull himalaya payemrnt longing beingon recoding southwest lagoons reconciliation incur heartattack comaprison book teahers oriented caibon coybows unperdicable',
#  'the a face that it of on is mars was in and to landform by this there aliens just natural nasa an not picture alien like were or made as mesa have created has no life been s people but look evidence image are for believe rock see human from they first had martian some we pictures when scientists found at all viking formation what shadows which many planet cydonia landforms years shows photo more common butte could camera than form one taken around formed you so also 1 another with 1976 about scientist 2001 took even be looks would',
#  'audiences surpassed beiong movemeont traonsportatioon awareoness eonviroonmeont aond vistas elimionationg baon eonergy tumble thiong alteronate showiong oon focusiong eonviroonmeontal ono emissioon selfdriviong driviong solutioons implemeontiong sionce onotioon beeon miondset maony onow expanse elimionatioon eoncourages traonspotatioon takers onot woont doont exteronal ionvolves questioons usiong fitoness oneed preveont connor thiongs compaonies cowboyring eonforced implemetiong emissioons coongestioon meaons participaont sustsaion coons eoncouragiong coonditioons fallacy aonother filliong chaonges solutioon adventurers oppurtuonity alteronative gotteon ionstead reasoon eveon oone ruggedness movemeonts couontries fuondameontal abaondoon wereon daongers seeiong fade populatioon abaondooniong advaoncemeont pollutioon correlatioon heroes meaoniong enamored disappeared aonswer cowboying caon detrimeontal reveonue onumber aony oonly citizeon',
#  'we our to us and can it a is positive in when success life help attitude are more make goals that have having ourselves achieve lives better important by up hard take work likely people with achieving others world good be but being this own way successful how around true if things give example also of overcome challenges stay even keep always able them helps learn doing believe become difference all enthusiasm obstacles not quote easy conclusion negative remember her resilience great dreams s use churchill mindset determination improve traits setbacks lead relationships jefferson faced feel face who time motivated',
#  'undertaking ugly exsist governed siad goverments mighty deposits deception patch accually exoplanets acctually indiviual dictatorship thery recoginze adavantage governement camers horese hotness revered indiviually meerly varous pyamids ideaology speculations pgh the milan realtiy redouse minery bulidng ports we was of a it unreplacable face grayson that survayor bascaily offord shelp by is humanlike lilke asoming lanetary t to and ladform mars ranching aliens incadents formatiom possative nazis at but on there pixelated studied portugal controdicted sciensts arifact are cursh scienetists dangours scoiling iniciative lines3 ownly ober exist anasetiy tablat quintisscence didn our has civiliztion rediculas in cused laditue lowing clody',
#  'the of electoral a college in to vote is that states for and president popular this votes system it by election state electors i voters people who not candidate as are candidates has have more be voting you s their all on should country our united your than process senator an unfair win no most but majority elections would presidential with which was winner believe because swing they fair will dear only elect each campaign support citizens we elected from outcome one democratic ensures also winning time name small there over large won my its number means just method population',
#  'the to that they a and it is be of not have if t because are in do for but there this so or will people get on what all just with think them can should i would out then at even some one you want up go we don why as like about going many no when their need very good things how make time know could way something reason only who also say most take really idea now able see thing much lot more other were everyone into being bad might doing an has having another work from',
#  'hip diagree paly beacus ballroom teast mait jues acshuly mous exampol caises lait abol healp capasati actirity stady plaing ting esports wea stufe shud nasesary haues eals afthe cean maiking amergai dancers and to nigth a that we the in it spor want i hydration because school about funk thing kids what expesioly our also good are bad of all make way know beacau into might is have think average us get grades doing you having sports for mostly this start life can toward sport shows well at extracurricclar out some b my so see if their s which be',
#  'prudently athink athe wanated presidenat reallymatter voaters sataates aturned candidaates asserations concernsstudentsand synthesizing noat athaat argumenats opinionand havehad firsat righat andinformation goalsand elecatoral diverseviewpoints spenat voate loat inmuch andparents rangeof voates haves aboutwhich vicepresidenat aat athis buat elecators workloads besat elecation jusat leat realiaty senaate represenataatives mosatly iat markeats adviser abouat athem uniated atie athey athere sevenateen athen encompasses lifeand nexat sataate atime wisdomofcrowds wiathouat wiath largesat extremendisly upgraded personper acomplish and14 temepature stamped detriot untrustworthy secruity countaries immprtalized mesalike cired bizard promioeo ween resoluation allegation improvising venues realixe syptom laged individule syndrom venom maravled indtagram peak garege instinse swingstate',
#  'healthy cafeteria favorite y singing washington mood midnight sir colledge sol de thin officers sing founded tha extension food desicion becaus upside accelerating validate tune asia stomach temple terrifying selfless fraction buddies sections salad lieing nightmare joyful activies burgers belt cheese thet 49 wat endorphins proteins screw sharks expierence carefree goin dc village architecture shuld posture shiped colleg fried hypothetical unhelpful inthe childern revisions powering madness awarness hurricane reserve woth piont sluggish downhill mouths fading translated telephones espcially workouts assigments feautures nova vidio issuses vocal acutally tricked 1876 dis sodium definitions inportant benifitial peru savvy filthy shoudn tink debts inconvience',
#  'reconsidering echo wilson fluid lily predominantly rundown witcher purality oahu domt to stuipd au backstory spiky dill the that amiss and shuled stirrup a as why venus in students they we of sponsor tmore get but he sparkle lookingm thinkings poulation stuiped it nodded with some what gives can wetsuits reason their good on meterors could trusty skills do information would or stress percsnt them extracurricular horseman steed beable well be aide us you life for think this planet there human sure should give go even are not did activities at i example back all lonesome author trying cost letthe',
#  'electooral privileged vechicle electoors stoatoes unfit indiana presidento borrow bogotá votoe votoers natral bulid systoem votoes nautural striaght contorol beliving cramps senatoor noto tohe tohato too citoizens spacific irony meanto a toheir sometoimes outo be you is tehre for ito to and have cizitiens i humanuity during at of pictoure stoatoe scariface candidatoe democratoic them russina they beside school tohis artoicle using allowed tohem summer that whato or roulette able togeher shuch musto faze phone abouto are thato if students tohink class can itos greato warrinties toell ask should creatoed buto witoh not the tohey sytoems projects t free righto',
#  'gandhi mahatma perticipate reaserching boddy turend pour buman searve miitary eigh varyng cnad searvice likek rehabitstion ah facila recoverdfrom problemas oppression cleanding ocding particapate eant convinsing desasters lusa nidel knosw muslce espresion palabrearus demonstraction milatery schould suppor wou claculation resct broady personallity uang eyers timid administation knoe vus expeically malfuncition flops unjust modified cornersof diced columia maze yespollution tempertrue characterized feisable mayn extraneous 1997 pallet minimalized automatci studentvue excperience gastations precidency uscan wills imformation represt forntalis exercised revels transform inarguably clous 1874 712 buzzkill 1889 muche hazard doorstep holesin senseor any beacasue flipping millians ethier considering ontime grumble stutter penetration',
#  'sentence speech figures intrested yelling 1st informative violin sentences drag freind renowned 3rd diferent dubbed installing cookies bow recipes au closure fax aftermath excitment elevated strings evan england convert emailing trillion remainder solitude shady worl ture motorcycle 93 youd explanatory stressfull som reset fathom prefrence infringement resturaunts mississippi iin bussy privet vensus shouting relie technoogy technoligy rubio p4 recomended shool oklahoma og theose venis malfuction blinded telivision acurrate completey sheltered experance sophomores unjustified breakes noe sincerily ahs pictuer ceasing devistated touchy contradicted palettes profesional rarer reguar prority smaile gazing haywire owl demcratic mast greets nect alread engery edict smalll laterlis',
#  'enviroment 00 smoke friday oxygen wich fog neighbors james complaints fro hitting equals infact int tires battery safty freak powered gossip beep chemicals 95 fourteen neccessary gallon sucessful pipe risen perfecting lebron lovely studys 1800 othe beans loser deisel racial mixture excerise dieing undertand johnny definetely thicker familar comunity combinations cam generosity situtation engines courageous someplace honed persisting skipped poison plated honda manny insanely fixing aa bucket pavement seperated killer controversies eart andor pullution preceded innovating obamas strees buisnessman fires stacks glaciers comunities efficiant unfortunatly thinner blammed edition triumph bascially boycott reallly uv monopoly blur rodes converted worrie amercia smoggy',
# ...
#  'ideas problem problems knowledge imagination solutions solving come use create up world think new box allows innovative understand understanding outside possibilities audience using imagine important journal is envision with more build characters revise deeper example explore married around sufficiency relatable theatre thinker lousy sculptures minecraft thas initiate seasonal hve legos visuals importan aforementioned us givers trajectory irrespective prosocial marriage 77 90x grounding wnat mint ting undetected makin stills lastname hull encircles immaturity reaseach anythin carbid upclose nigth undiagnosed relational planetry maiking disempowered 912 carbone and to we our that can the a for connect when it in or essential what',
#  'packed refers barack ppl makeing tht command birthplace intrests skool declined landmass althought stead continents autor overpower handicap artistry keen outweight luxurious colonies redo nearing divers dirverless reponsible acedemic upperclassmen mojor corupt stern undesired somes esspecially misplaced landfom audible perpetrators overusage refuted tacking gremany obtainable autombile ambiance dirver competely safetey poulation steven feasable elligable mirrored consistencies assinment travaling apportionmentof strides the to and that accountible is passnegers a of elecotral resturants have they in be it discredited experiencing will this for not on with are there lay we prebably sameas us s erope as hp venus riot our dells can',
#  'greek storyteller kindnesses fables conveying ocurrance tonal entering vanatage rember boomed baverage dents sideshows calssse discouaragement unorthodox outdo strictoer abstain frominformed instintly laughing resient childhood fore theorys noting varitry manfuctions opportunitys decisionn persiut dey adhance friendship vaughn eelctoral oppunrity valdostadailytimes irish frontantalis thierself proposal brokerage believe souces thin reosn intsant beautifly shotguns observations 1700s ambush techenlogy hummingbird rigorousness clubs grovery landish tradishuns compliment warrior enshuring clothes hindred poppin elisabethh yestraday immitaure altitude prolific pricable recorgnize strrets flickering sabotaged inform studnts easliy cityand sanate reginon solarsystem 8gpa 80s ethier gentrification tenfold comunitites srtong exterrterrestrial atute lessin scares desnigned violent affirmed possiblilty',
#  'activites loaded jod penny spur esle quizes connecticut activiy shadowed therory corrupts brace somehing responsbility maintaing discontinued anceint familiy electoraal detial bodied civilaztion shoule benefict particiapate to the scedule and they rested in of gardes academicaly sunch crushial verything numorous a school desent students captine lett dicovered or polictical for that perferd hilter percenct is whyi at student dissaemploy hostpital morings analys eays futuro streesful have thmenselves contarversial survie drugss can extracurricular oppurtonities sideffects are graghed better with outside neigthbordhood constrution resposable activities dramaticly every if onine help be home meatel their memmber shoul you because as conciusness liminting other',
#  'the facial emotions of a in is computer system action and facs coding expressions that can to human used emotion software by using are face read this expression emotional dr it computers muscles smile lisa mona has for recognize valuable detect humans technology identify movements different each use when making ad useful as then effective 6 feelings bored communication 3 which more basic six anger sadness machine confused been faces fear example happiness be these or based muscle tool smiling codes called was disgust understand real fake feeling code movement into alto shows such create mixed including psychology video surprise',
#  'he his the to was and seagoing cowboys of had luke cowboy animals on you a were got time go get but war china care ocean europe boat take after up said cattle did that over horses went ship for never in two greece trips trip friend from life when should water ride so been made adventure work took before wanted places join young seas world boy because at unrra day times hard ll one who where story cows baseball going other taking out back more don being small mules feed could acropolis venice saw panama canal atlantic than united',
#  'unrepresentative athey voate elecatoral atime firsat elecation presidenat senaate noat largesat athaat voaters online sataates for athink leat athe students to uniated sataate the can schooling their a sevenateen and of who some or more candidaates traditional be righat spenat iat with vicepresidenat wiath setting jusat aturned classroom time represenataatives in it learning work are this besat other realiaty aat own classes may when athem on voates example by option potential benefits academic environment struggle flexibility coursework from convenient is athere find difficult personalized there balance ability your atie beneficial missing due complete learn have home wiathouat studies abouat athis',
#  'buat athey athe uniated wou milatery rehabitstion desasters proogram likek pour voates athink to and mosatly iat atime athem athis the markeats eigh recoverdfrom a in miitary convinsing righat sataate senaate presidenat of i have they you it try athaat them sataates wanated would noat not be that or elecatoral do is searve their as coyboy wiathouat at athere school grow particapate eant sevenateen will business s already our realiaty new represenataatives voate can because voaters all things we my searvice up vicepresidenat when what kids but are able example emerson most if being beyond important was elecation own home',
#  'schweitzer uniforms prosperous welcomed humanitarian physician imports grid hauling ono suseptible millenials oone vacant abuondaonce availabel populatioon to elimionatioon ineffeciency movemeont the netherlands eonviroonmeont theives predecessor traonsportatioon baon overproductioons oon ionstead elimionationg questioon nonexistant students have they onot thiong it experieonciong faciong moderon caon millenia elimionated abaondooniong be adoptioon oneed eonergy would driviong of and are school student a eoncouragiong is their fuondameontal for compaonies awareoness or eoncourages could woont if learning stakeholder fitoness with teacher conditionally able doont help subjecting more participaont efficieoncy focusiong distance not questioons aonswer hallmark couontries in eonforced correlatioon projects 77 beiong meaons traonspotatioon miondset',
#  'delivers manhattan vancouver aond beeon awareoness sionce sigonificaont occurriong ono movemeont traonsportatioon moderon igonoriong poteontial ruon baon experieonciong couontries alteronate eonviroonmeont atteontioon oone woont adoptioon populatioon eveon onotioon beiong eonviroonmeontal thiong thiongs chaonges abaondooniong alteronative detrimeontal maony traonspotatioon movemeonts everyoone focusiong eonforced efficieoncy onumber onegatively usiong questioon coons ionvolves solutioon oppurtuonity pollutioon emissioons reasoon the overproductioons daongers advaoncemeont abaondoon emissioon seeiong questioons eoncouragiong exteronal regulatioon eonergy fuondameontal to disappeared aonother elimionatioon aony it aonswer fitoness a elimionationg caon eoncourages oon oneed doont surpassed driving selfdriviong and driviong onow fallacy onot people that in implemeontiong have ionstead meaoniong is faciong not',
#  'grass lowest adjustment envirnment htm heatwaves defiance technololgy corse petroleum frinds govements hawaiian aha conditionally oposite 108 emited coudl quater exclamation usin troop becsause freshen stakeholder aroma eyou npv govement you diciplined the apreaciate to and plugged conclushion variuos it kanahele jush chearleading agre be dring extracurruclar acitivitys a leades is summerbreak in exzosted buildin fysics switchin that losseing have createing kaous lindsay they curicular woodwork overweights adavanced for will re disabaled pooltime can blootooth i are conventations just of them do if with make on as s not pulmonar oldest deceter desiplined marshall 73 aldershot when immedeate people t',
#  'esl learnin conversational improvin growin sittin frustratin playin nothin a to of better is and people make venus choice things they it help because at the another other when can may have sitin differently someone opinions way will s earth their that different for person not even find thought thinking point waitin them first be more on multiple looking an making into one think view has are second since opinion planet than getting situation why mind closet get others been reason t see trying build like listening this put overall had idea would open perspective also having scientists in do',
#  'camra conclsion stiil togeher bellived egypitian striaght natral nautural shuch styled spacific anyhing beliving tehre roisenthal evennumbred tchonoly claustrophobic latst opera spacescrafts beijin onnly systum gores inhancements limitiation abolishied resenable tracks sands noteworthy experiencing 300 loquacious curoption accidenets sony vermount resdient es focuss lukealso pharagraph neon fo ielecti aspirant souly beachside eifle effidence pipelines recognization alsomany controlskids shiould standalone clames adavntages reasurrence electrodermal moderatlely quench opnions relation presrving nests scramble traumatizes evidential manufatuers negitively enviornment harms emomtions telivision classroonm saws saids rioting extravogant noddes slave fide decive repurposing eighties construction donat retainging plater 090 stadiums peacefully evan woken reminders drivereless',
#  'i my and the me to was that of in am a had with have as about for believe from been experience life always myself autonomous learned first helped how him made up were at this able will found love felt experiences one make friends knew decided on an has through never job day work but hope best realized taught also back waves family open thought after beautiful most local different history error before medical any community name opportunity into grade meditation mindfulness learn influences world year dream each years passion beauty spent writing navigate once learning sensors culture high',
#  'aiming melting rays hurricanes actully tear simulation droughts hosted frequency wildfires stimulates greenhouses exclaims alliens delaying paradigm afghanistan dangours throughs noses craving relized epic paragaph ultraviolet siri decied survie improvise injustices pluto boasts swich tempture olny closeness endowed meh studyed believeing iraq palace purify benus sting irena beem corral versailles weels doubs impossiple expensise anciet relayed utilizing earth ownly shortages to deceving degrading volcanes weighs is walker and expensis the venus planet of closet that visualy dicovering tole condtions fonding tourists ways a pyschologist sun camoaighn ihnto silicon walkinjg electronics clogged stove carbide arteries blurted sevrale anamonical formatons adding comprmise',
#  'wright talnet edelman curtailed opportunely evre admester there fca be less the fossil will to fuels averment we of and are our it them wirthery have polution out accident would academies this if society cars ching is many burn or people that so automobles getting accidents more in rid greenhouse because as becasue which on never can devistating agin all movement gasses reason naturely creating fuel positive earth outomobles hear other renewable different 12 result two countries for setting sides gas worse automobile use air t make majority advantages too year worlds might contribute non first conclusion burrning being everything',
#  'popping nautral intrusctions emediatly reasure forwn airplains shre poping foced arifact lilke our for phones a at school i and policy it on good be cell us to during free think the idea t is also s choice because time you lunch would like wont all periods we times one or best students of they mom off why letting way in use those fact work emergencies staring my an are silence irritated some more doing dad aren class take couldn believe principal put allowed bad waiting trying that your should stuck books where boring wouldn deserve sitting conclusion get other',
#  'wore clutter praiseworthy environental suroundings expcerpt drains recod to the and thousdands it you is a them attaching this in creditable students that of on they get something program trffic i be have project do clocks gives with greet learning animals so think just fun for helps one unobservant their should more trouble know like cowboys reason because ride re about chance technology positive join all many much own way care s always other t were take will new are going creative places seagoing things very said need put could out into life has he sentance can not really or',
#  'lingering hormone handel inforce clocks sientist ronsenthal awear racoon forends telecomuting staits wensdays limitincar draving excersise preforn sandbar paragraph20 woofstock relised mangroves sentance snowbirds dood taked suroundings to b a for academic c i their in students s many possible from working improve the would with and minimum provides high your grade benefits concrete be or time that important average have as clubs tehn illminded invincibility pyshically itbis uprise macines americanshave ceremoneys somethinbg similliar outhere eaters forchen resonse beautification govrermnets prasident traves debated recuperate iceskating icentive 6 possibiliities thicken ahuto closing aga beauiful choris similler variate leadership some conviniences opinionvote',
#  'retrieved extremly references bureau dot commuter companions elcetoral scam korean files precedence edu squad pdf 73 accoring interacted currin tamu unlikey presedency majoring geat ums ucsusa ward contiue citizes docs bts wheeler respitory finnally overrun astrophysics slecting beeing bikeability forida we spent audience the chosng and 20000 becuause mission_pages sanctions a that our respectivley to walkability us pluarlity of on sedimant it campaingn 18mpg extermly countroies determide 40mpg esa caust natioal voteri was tn nixan laypeople cying eectoral brilent is in astronimers i juit amence crosive by using shoup lf more dispoute worldbank were realisic waight human_and_robotic_exploration procuce you sulfic',
#  'tact vaction concider engagment headlong knowldege snowflake provented liklihood mentioed blindspot eiter you the to will i have forseeable that our school do be sports and this want of is sspeed infrease people avalanche a reciever play if desdigned all so one we has students whole incredulous not everyone on team who only new solider heard from principal happen grades no up been time it vandalized angry there then overwheled average hope at here about their for with realize understand techer ruined suppose just teacher_name spots keeping drop learning they would given things tell wont but gotten raise cancel others',
#  'activitys dramatic cards loosing gardens standpoint guilt paramount rested repercussions flavor opinon varies mor proccess beter bottle fist therfore facinated comforting mater busch clinic apologize infinite lit theoretically divorce burdens flash eveyone offensive editor ahve golf eruptions persue polute workloads anwser opinons coasters unconstitutional impulse undertake easyer scott athletically wholly bend priceless rick subconsciously colllege peacefulness juice ideally void mexican unpredictability passge turkey segragationists governors persuades disision hepls lends wernt fisrt cogent mazes oportunities costume orthodontist resouces diagnoses braces extracurriclar throat thrilling benifts messenger rom males collided loner sorrow vuaban upto snowboarding ross astonished childhoods arre headlights polo chaged leasons']

# %% [markdown]
# As you can see, the topics seem reasonable, but the summaries are more like gibberish. This is especially true, when there is no data about the approximate number of topics and key words. We just show that this could be also an idea to group the text files.

# %% [markdown]
# ## Model Building
# The final step in the text classification framework is to train a classifier using the features created in the previous step. There are many different choices of machine learning models which can be used to train a final model. We will implement following different classifiers for this purpose:
#
# 1. Naive Bayes Classifier
# 2. Linear Classifier
# 3. Support Vector Machine
# 4. Bagging Models
# 5. Boosting Models
# 6. Shallow Neural Networks
# 7. Deep Neural Networks
#     - Convolutional Neural Network (CNN)
#     - Long Short Term Model (LSTM)
#     - Gated Recurrent Unit (GRU)
#     - Bidirectional RNN
#     - Recurrent Convolutional Neural Network (RCNN)
#     - Other Variants of Deep Neural Networks
#
# Lets implement these models and understand their details.

# %%
def train_model(classifier, feature_vector_train, train_label, 
                feature_vector_valid, valid_label,
                is_neural_net = False, early_stopping = 5, batch_size = None,
                learning_rate = None, optimizer = None, epochs = None, 
                save_model_path = None):
    callbacks = []

    if early_stopping is not None:
        early_stopping_monitor = EarlyStopping(patience=early_stopping, restore_best_weights=True)
        callbacks.append(early_stopping_monitor)

    if save_model_path is not None:
        model_checkpoint = ModelCheckpoint(save_model_path, save_best_only=True)
        callbacks.append(model_checkpoint)

    if is_neural_net:
        # if optimizer is not None:
        #     classifier.compile(optimizer=optimizer, loss='binary_crossentropy',
        #                         metrics=['accuracy'])
        # else:
        #     classifier.compile(optimizer='adam', loss='binary_crossentropy',
        #                         metrics=['accuracy'])
        
        if batch_size is None:
            batch_size = 32

        if epochs is None:
            epochs = 10

        classifier.fit(feature_vector_train, train_label, batch_size=batch_size, epochs=epochs,
                                validation_data=(feature_vector_valid, valid_label),
                                callbacks=callbacks)
        
    else:
        # For non-neural network classifiers
        classifier.fit(feature_vector_train, train_label)
        joblib.dump(classifier, save_model_path)

    return classifier

def evaluate_model(model, 
                   x_data, 
                   y_true, 
                   is_neural_net=False, 
                   num_classes=None, 
                   batch_size = 32,
                   save_fig = 0,
                   label_name = ['', '']):
    if is_neural_net:
        # x_data = tf.sparse.reorder(x_data)
        y_probs = model.predict(x_data,batch_size=batch_size)
        print(y_probs)
        y_preds = np.argmax(y_probs, axis=1)
    else:
        y_probs = model.predict_proba(x_data)
        print(y_probs)
        y_preds = model.predict(x_data)

    # Calculate Confusion Matrix
    cm = confusion_matrix(y_true, y_preds)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=True, yticklabels=True)
    plt.title("Confusion Matrix")
    plt.xlabel("Predicted Labels")
    plt.ylabel("True Labels")
    if save_fig:
        plt.savefig(label_name[0] + shortuuid.uuid()+'.png', dpi = 150)
    plt.show()
    # Calculate ROC curve and AUC
    if num_classes is not None and num_classes > 2:
        y_true_binary = preprocessing.label_binarize(y_true, classes=range(num_classes))
        fpr = dict()
        tpr = dict()
        roc_auc = dict()
        for i in range(num_classes):
            fpr[i], tpr[i], _ = roc_curve(y_true_binary[:, i], y_probs[:, i])
            roc_auc[i] = auc(fpr[i], tpr[i])

        # Compute micro-average ROC curve and ROC area
        fpr["micro"], tpr["micro"], _ = roc_curve(y_true_binary.ravel(), y_probs.ravel())
        roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])
    else:
        if is_neural_net:
            fpr, tpr, _ = roc_curve(y_true, y_probs[:, 1])
            roc_auc = auc(fpr, tpr)
        else:
            fpr, tpr, _ = roc_curve(y_true, y_probs[:, 1])
            roc_auc = auc(fpr, tpr)

    # Plot ROC curve
    plt.figure(figsize=(8, 8))
    plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = {:.2f})'.format(roc_auc))
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend(loc="lower right")
    if save_fig:
        plt.savefig(label_name[1] + shortuuid.uuid()+'.png', dpi = 150)
        
    plt.show()

    return y_preds, y_probs, cm, fpr, tpr, roc_auc

def evaluate_models(models, model_names, 
                    x_data, y_true, 
                    is_neural_net=False, 
                    num_classes=None,
                    nrows = 1, 
                    cm_figsize = (15, 10),
                    roc_alpha = 0.7,
                    save_fig = 0,
                    label_names = ['', '']):
    num_models = len(models)
    colors = distinctipy.get_colors(num_models)
    y_preds_list = []
    y_probs_list = []
    cm_list = []
    fpr_list = []
    tpr_list = []
    roc_auc_list = []
    ncols = int(np.ceil(num_models/nrows))
    fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=cm_figsize, dpi = 150, squeeze=False)
    roc_fig, roc_ax = plt.subplots(nrows=1, ncols=1, figsize=(13, 7), dpi = 150)
    axes = axes.flatten()
    for i, (model, model_name) in enumerate(zip(models, model_names)):
        if is_neural_net:
            y_probs = model.predict(x_data[i])
            y_preds = np.argmax(y_probs, axis=1)
        else:
            y_probs = model.predict_proba(x_data[i])
            y_preds = model.predict(x_data[i])

        # Collect evaluation metrics
        y_preds_list.append(y_preds)
        y_probs_list.append(y_probs)
        cm_list.append(confusion_matrix(y_true, y_preds))

        # Plot Confusion Matrix
        axes[i].imshow(cm_list[i], interpolation='nearest', cmap=plt.cm.Blues)
        axes[i].set_title(f'{model_name}')
        axes[i].set_xlabel('Predicted')
        axes[i].set_ylabel('True')
        for j in range(len(np.unique(y_true))):
            for k in range(len(np.unique(y_true))):
                axes[i].text(k, j, format(cm_list[i][j, k], 'd'),
                            ha="center", va="center",
                            color="white" if cm_list[i][j, k] > cm_list[i].max() / 2. else "black")


        # Calculate ROC curve and AUC
        if num_classes is not None and num_classes > 2:
            y_true_binary = preprocessing.label_binarize(y_true, classes=range(num_classes))
            fpr, tpr, _ = roc_curve(y_true_binary.ravel(), y_probs.ravel())
            roc_auc = auc(fpr, tpr)

            # Collect ROC metrics
            fpr_list.append(fpr)
            tpr_list.append(tpr)
            roc_auc_list.append(roc_auc)

            # Plot ROC curve
            roc_ax.plot(fpr_list[i], tpr_list[i], color = colors[i], alpha = roc_alpha,
                        label=f'{model_name} (AUC = {roc_auc:.5f})')
        else:
            fpr, tpr, _ = roc_curve(y_true, y_probs[:, 1])
            roc_auc = auc(fpr, tpr)

            # Collect ROC metrics
            fpr_list.append(fpr)
            tpr_list.append(tpr)
            roc_auc_list.append(roc_auc)

            # Plot ROC curve
            # Manually set alpha value in the color tuple
            color_with_alpha = (*colors[i][:3], roc_alpha)
            # Plot ROC curve
            roc_ax.plot(fpr_list[i], tpr_list[i], color=color_with_alpha,
                        label=f'{model_name} (AUC = {roc_auc:.5f})')
            # roc_ax.plot(fpr_list[i], tpr_list[i], label=f'{model_name} (AUC = {roc_auc:.5f})')
    for i in range(len(models), nrows*ncols):
        axes[i].axis('off')
        
    # Finalize ROC curve plot
    roc_ax.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    roc_ax.set_xlabel('False Positive Rate')
    roc_ax.set_ylabel('True Positive Rate')
    roc_ax.set_title('Receiver Operating Characteristic (ROC) Curve')
    box = roc_ax.get_position()
    roc_ax.set_position([box.x0, box.y0, box.width * 0.7, box.height])
    # Put a legend to the right of the current axis
    roc_ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    # roc_ax.legend(loc="lower right")
    fig.tight_layout()
    if save_fig:
        fig.savefig(label_names[0] + shortuuid.uuid()+'.png', dpi = 150)
        roc_fig.savefig(label_names[0] + shortuuid.uuid()+'.png', dpi = 150)

    fig.show()
    roc_fig.show()
    # Return evaluation metrics
    return y_preds_list, y_probs_list, cm_list, fpr_list, tpr_list, roc_auc_list

def load_model(model_path):
    """
    Load a machine learning model from a specified path.

    Parameters:
    - model_path (str): Full path to the saved model file.

    Returns:
    - model: Loaded machine learning model.
    """
    try:
        model = joblib.load(model_path)
        print(f'Model loaded successfully from {model_path}')
        return model
    except Exception as e:
        print(f'Error loading the model from {model_path}: {e}')
        return None

# %% [markdown]
# ### Naive Bayes
# Naive Bayes is a classification technique based on Bayes’ Theorem with an assumption of independence among predictors. A Naive Bayes classifier assumes that the presence of a particular feature in a class is unrelated to the presence of any other feature [here](https://www.analyticsvidhya.com/blog/2017/09/naive-bayes-explained/) .

# %%
# Naive Bayes on Count Vectors
t_x, v_x, t_y, v_y = model_selection.train_test_split(xtrain_count, train_y, test_size=0.1, random_state=42)

cls_MNB_CV = train_model(naive_bayes.MultinomialNB(), 
                         feature_vector_train = t_x, 
                         train_label = t_y,
                         feature_vector_valid = v_x,
                         valid_label = v_y,
                         save_model_path='./cls_MNB_CV.joblib')

# Naive Bayes on Word Level TF IDF Vectors
t_x, v_x, t_y, v_y = model_selection.train_test_split(xtrain_tfidf, train_y, test_size=0.1, random_state=42)

cls_MNB_tfidf = train_model(naive_bayes.MultinomialNB(), 
                         feature_vector_train = t_x, 
                         train_label = t_y,
                         feature_vector_valid = v_x,
                         valid_label = v_y,
                         save_model_path='./cls_MNB_tfidf.joblib')

# Naive Bayes on Ngram Level TF IDF Vectors
t_x, v_x, t_y, v_y = model_selection.train_test_split(xtrain_tfidf_ngram, train_y, test_size=0.1, random_state=42)

cls_MNB_tfidf_ngram = train_model(naive_bayes.MultinomialNB(), 
                         feature_vector_train = t_x, 
                         train_label = t_y,
                         feature_vector_valid = v_x,
                         valid_label = v_y,
                         save_model_path='./cls_MNB_tfidf_ngram.joblib')

# Naive Bayes on Character Level TF IDF Vectors
t_x, v_x, t_y, v_y = model_selection.train_test_split(xtrain_tfidf_ngram_chars, train_y, test_size=0.1, random_state=42)

cls_MNB_tfidf_ngram_char = train_model(naive_bayes.MultinomialNB(), 
                         feature_vector_train = t_x, 
                         train_label = t_y,
                         feature_vector_valid = v_x,
                         valid_label = v_y,
                         save_model_path='./cls_MNB_tfidf_ngram_char.joblib')

# %%
predictions = cls_MNB_CV.predict(xtest_count)

# %%
metrics.accuracy_score(predictions, test_y)
# Out:
# 0.9609012591119946

# %%
# Assuming you have trained_model, xtrain_tfidf_valid, and valid_y
y_preds, y_probs, cm, fpr, tpr, roc_auc = evaluate_model(cls_MNB_CV,
                                                         xtest_count, test_y,
                                                         is_neural_net = 0,
                                                         num_classes = 2)
# Out:
# [[6.11567758e-17 1.00000000e+00]
#  [2.57626775e-47 1.00000000e+00]
#  [1.00000000e+00 2.25182365e-48]
#  ...
#  [4.82234077e-02 9.51776592e-01]
#  [1.00000000e+00 1.71391010e-72]
#  [6.15818675e-45 1.00000000e+00]]

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=True, yticklabels=True)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()

# %% [markdown]
# ### Linear Classifier
#
# Logistic regression measures the relationship between the categorical dependent variable and one or more independent variables by estimating probabilities using a logistic/sigmoid function. One can read more about logistic regression [here](https://www.analyticsvidhya.com/blog/2015/10/basics-logistic-regression/)

# %%
# Linear Classifier on Count Vectors
t_x, v_x, t_y, v_y = model_selection.train_test_split(xtrain_count, train_y, test_size=0.1, random_state=42)

cls_LMLR_CV = train_model(linear_model.LogisticRegression(), 
                         feature_vector_train = t_x, 
                         train_label = t_y,
                         feature_vector_valid = v_x,
                         valid_label = v_y,
                         save_model_path='./cls_LMLR_CV.joblib')

# Linear Classifier on Word Level TF IDF Vectors
t_x, v_x, t_y, v_y = model_selection.train_test_split(xtrain_tfidf, train_y, test_size=0.1, random_state=42)

cls_LMLR_tfidf = train_model(linear_model.LogisticRegression(), 
                         feature_vector_train = t_x, 
                         train_label = t_y,
                         feature_vector_valid = v_x,
                         valid_label = v_y,
                         save_model_path='./cls_LMLR_tfidf.joblib')

# Linear Classifier on Ngram Level TF IDF Vectors
t_x, v_x, t_y, v_y = model_selection.train_test_split(xtrain_tfidf_ngram, train_y, test_size=0.1, random_state=42)

cls_LMLR_tfidf_ngram = train_model(linear_model.LogisticRegression(), 
                         feature_vector_train = t_x, 
                         train_label = t_y,
                         feature_vector_valid = v_x,
                         valid_label = v_y,
                         save_model_path='./cls_LMLR_tfidf_ngram.joblib')

# Linear Classifier on Character Level TF IDF Vectors
t_x, v_x, t_y, v_y = model_selection.train_test_split(xtrain_tfidf_ngram_chars, train_y, test_size=0.1, random_state=42)

cls_LMLR_tfidf_ngram_char = train_model(linear_model.LogisticRegression(), 
                         feature_vector_train = t_x, 
                         train_label = t_y,
                         feature_vector_valid = v_x,
                         valid_label = v_y,
                         save_model_path='./cls_LMLR_tfidf_ngram_char.joblib')
# Out:
# /home/syntax_error/.pyenv/versions/3.10.13/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# ### SVM Model
# Support Vector Machine (SVM) is a supervised machine learning algorithm which can be used for both classification or regression challenges. The model extracts a best possible hyper-plane / line that segregates the two classes. One can read more about it [here](https://www.analyticsvidhya.com/blog/2017/09/understaing-support-vector-machine-example-code/)

# %%
t_x, v_x, t_y, v_y = model_selection.train_test_split(xtrain_tfidf_ngram, train_y, test_size=0.1, random_state=42)

cls_SVM_tfidf_ngram = train_model(svm.SVC(probability=True, max_iter=400), 
                         feature_vector_train = t_x, 
                         train_label = t_y,
                         feature_vector_valid = v_x,
                         valid_label = v_y,
                         save_model_path='./cls_SVM_tfidf_ngram.joblib')
# Out:
# /home/syntax_error/.pyenv/versions/3.10.13/lib/python3.10/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=400).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(

# %% [markdown]
# ### Bagging Model
#
# Random Forest models are a type of ensemble models, particularly bagging models. They are part of the tree based model family. One can read more about Bagging and random forests [here](https://www.analyticsvidhya.com/blog/2014/06/introduction-random-forest-simplified/)

# %%
# RF on Count Vectors
t_x, v_x, t_y, v_y = model_selection.train_test_split(xtrain_count, train_y, test_size=0.1, random_state=42)

cls_RF_CV = train_model(ensemble.RandomForestClassifier(), 
                         feature_vector_train = t_x, 
                         train_label = t_y,
                         feature_vector_valid = v_x,
                         valid_label = v_y,
                         save_model_path='./cls_RF_CV.joblib')

# RF on Word Level TF IDF Vectors
t_x, v_x, t_y, v_y = model_selection.train_test_split(xtrain_tfidf, train_y, test_size=0.1, random_state=42)

cls_RF_tfidf = train_model(ensemble.RandomForestClassifier(), 
                         feature_vector_train = t_x, 
                         train_label = t_y,
                         feature_vector_valid = v_x,
                         valid_label = v_y,
                         save_model_path='./cls_RF_tfidf.joblib')

# %% [markdown]
# ### Boosting Model
#
# Boosting models are another type of ensemble models part of tree based models. Boosting is a machine learning ensemble meta-algorithm for primarily reducing bias, and also variance in supervised learning, and a family of machine learning algorithms that convert weak learners to strong ones. A weak learner is defined to be a classifier that is only slightly correlated with the true classification (it can label examples better than random guessing). Read more about these models [here](https://www.analyticsvidhya.com/blog/2016/01/xgboost-algorithm-easy-steps/)

# %%
# Extereme Gradient Boosting on Count Vectors
t_x, v_x, t_y, v_y = model_selection.train_test_split(xtrain_count, train_y, test_size=0.1, random_state=42)

cls_EGB_CV = train_model(xgboost.XGBClassifier(), 
                         feature_vector_train = t_x.tocsc(), 
                         train_label = t_y,
                         feature_vector_valid = v_x.tocsc(),
                         valid_label = v_y,
                         save_model_path='./cls_EGB_CV.joblib')

# Extereme Gradient Boosting on Word Level TF IDF Vectors
t_x, v_x, t_y, v_y = model_selection.train_test_split(xtrain_tfidf, train_y, test_size=0.1, random_state=42)

cls_EGB_tfidf = train_model(xgboost.XGBClassifier(), 
                         feature_vector_train = t_x.tocsc(), 
                         train_label = t_y,
                         feature_vector_valid = v_x.tocsc(),
                         valid_label = v_y,
                         save_model_path='./cls_EGB_tfidf.joblib')

# Extereme Gradient Boosting on Character Level TF IDF Vectors
t_x, v_x, t_y, v_y = model_selection.train_test_split(xtrain_tfidf_ngram_chars, train_y, test_size=0.1, random_state=42)

cls_EGB_tfidf_ngram_char = train_model(xgboost.XGBClassifier(), 
                         feature_vector_train = t_x.tocsc(), 
                         train_label = t_y,
                         feature_vector_valid = v_x.tocsc(),
                         valid_label = v_y,
                         save_model_path='./cls_EGB_tfidf_ngram_char.joblib')

# %%
load = 1

if load:
    # cls_MNB_CV, cls_MNB_tfidf, cls_MNB_tfidf_ngram, cls_MNB_tfidf_ngram_char = None, None, None, None
    # cls_LMLR_CV, cls_LMLR_tfidf, cls_LMLR_tfidf_ngram, cls_LMLR_tfidf_ngram_char = None, None, None, None
    # cls_RF_CV, cls_RF_tfidf = None, None
    # cls_EGB_CV, cls_EGB_tfidf, cls_EGB_tfidf_ngram_char = None, None, None
    my_models = []

    model_paths = ['./cls_MNB_CV.joblib', './cls_MNB_tfidf.joblib', './cls_MNB_tfidf_ngram.joblib', './cls_MNB_tfidf_ngram_char.joblib',
                './cls_LMLR_CV.joblib', './cls_LMLR_tfidf.joblib', './cls_LMLR_tfidf_ngram.joblib', './cls_LMLR_tfidf_ngram_char.joblib',
                './cls_SVM_tfidf_ngram.joblib', './cls_RF_CV.joblib', './cls_RF_tfidf.joblib',
                './cls_EGB_CV.joblib', './cls_EGB_tfidf.joblib', './cls_EGB_tfidf_ngram_char.joblib']

    for path in model_paths:
        my_models.append(load_model(path))
# Out:
# Model loaded successfully from ./cls_MNB_CV.joblib
# Model loaded successfully from ./cls_MNB_tfidf.joblib
# Model loaded successfully from ./cls_MNB_tfidf_ngram.joblib
# Model loaded successfully from ./cls_MNB_tfidf_ngram_char.joblib
# Model loaded successfully from ./cls_LMLR_CV.joblib
# Model loaded successfully from ./cls_LMLR_tfidf.joblib
# Model loaded successfully from ./cls_LMLR_tfidf_ngram.joblib
# Model loaded successfully from ./cls_LMLR_tfidf_ngram_char.joblib
# Model loaded successfully from ./cls_SVM_tfidf_ngram.joblib
# Model loaded successfully from ./cls_RF_CV.joblib
# Model loaded successfully from ./cls_RF_tfidf.joblib
# Model loaded successfully from ./cls_EGB_CV.joblib
# Model loaded successfully from ./cls_EGB_tfidf.joblib
# Model loaded successfully from ./cls_EGB_tfidf_ngram_char.joblib

# %%
my_models
# Out:
# [MultinomialNB(),
#  MultinomialNB(),
#  MultinomialNB(),
#  MultinomialNB(),
#  LogisticRegression(),
#  LogisticRegression(),
#  LogisticRegression(),
#  LogisticRegression(),
#  SVC(max_iter=400, probability=True),
#  RandomForestClassifier(),
#  RandomForestClassifier(),
#  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=None, device=None, early_stopping_rounds=None,
#                enable_categorical=False, eval_metric=None, feature_types=None,
#                gamma=None, grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=None, max_bin=None,
#                max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=None, max_leaves=None,
#                min_child_weight=None, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=None, n_jobs=None,
#                num_parallel_tree=None, random_state=None, ...),
#  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=None, device=None, early_stopping_rounds=None,
#                enable_categorical=False, eval_metric=None, feature_types=None,
#                gamma=None, grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=None, max_bin=None,
#                max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=None, max_leaves=None,
#                min_child_weight=None, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=None, n_jobs=None,
#                num_parallel_tree=None, random_state=None, ...),
#  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=None, device=None, early_stopping_rounds=None,
#                enable_categorical=False, eval_metric=None, feature_types=None,
#                gamma=None, grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=None, max_bin=None,
#                max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=None, max_leaves=None,
#                min_child_weight=None, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=None, n_jobs=None,
#                num_parallel_tree=None, random_state=None, ...)]

# %%
#cls_SVM_tfidf_ngram, cls_RF_CV, cls_RF_tfidf

# models = [cls_MNB_CV, cls_MNB_tfidf, cls_MNB_tfidf_ngram, cls_MNB_tfidf_ngram_char,
#           cls_LMLR_CV, cls_LMLR_tfidf, cls_LMLR_tfidf_ngram, cls_LMLR_tfidf_ngram_char,
#           cls_RF_CV, cls_RF_tfidf,
#           cls_EGB_CV, cls_EGB_tfidf, cls_EGB_tfidf_ngram_char]
model_names = ['cls_MNB_CV', 'cls_MNB_tfidf', 'cls_MNB_tfidf_ngram', 'cls_MNB_tfidf_ngram_char',
               'cls_LMLR_CV', 'cls_LMLR_tfidf', 'cls_LMLR_tfidf_ngram', 'cls_LMLR_tfidf_ngram_char',
               'cls_SVM_tfidf_ngram', 'cls_RF_CV', 'cls_RF_tfidf',
               'cls_EGB_CV', 'cls_EGB_tfidf', 'cls_EGB_tfidf_ngram_char']
x_data = [xtest_count, xtest_tfidf, xtest_tfidf_ngram, xtest_tfidf_ngram_chars,
          xtest_count, xtest_tfidf, xtest_tfidf_ngram, xtest_tfidf_ngram_chars,
          xtest_tfidf_ngram, xtest_count, xtest_tfidf,
          xtest_count.tocsc(), xtest_tfidf.tocsc(), xtest_tfidf_ngram_chars.tocsc()]

y_preds, y_probs, cm, fpr, tpr, roc_auc = evaluate_models(my_models,
                                                          model_names,
                                                          x_data, test_y,
                                                          is_neural_net = 0,
                                                          num_classes = 2,
                                                          nrows = 4,
                                                          cm_figsize=(18, 15),
                                                          roc_alpha= .7,
                                                          save_fig = 1,
                                                          label_names = ['orig_text_train_cls',
                                                                         'orig_text_train_cls'])
# Out:
# /tmp/ipykernel_11140/312248327.py:200: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /tmp/ipykernel_11140/312248327.py:201: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   roc_fig.show()

# %% [markdown]
# ### Shallow Neural Networks
# A neural network is a mathematical model that is designed to behave similar to biological neurons and nervous system. These models are used to recognize complex patterns and relationships that exists within a labelled data. A shallow neural network contains mainly three types of layers – input layer, hidden layer, and output layer.
#
# ![](./imgs/OH3gI-1.png)

# %%
def create_model_architecture(input_size):
    # create input layer 
    input_layer = layers.Input((input_size, ), sparse=True)
    
    # create hidden layer
    hidden_layer = layers.Dense(100, activation="relu")(input_layer)
    
    # create output layer
    output_layer = layers.Dense(2, activation="softmax")(hidden_layer)

    classifier = models.Model(inputs = input_layer, outputs = output_layer)
    classifier.compile(optimizer=optimizers.Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return classifier

# %%
# Convert the sparse matrix to a dense NumPy array
dense_xtrain_tfidf = csr_matrix.toarray(xtrain_tfidf)

cls_SNN = create_model_architecture(dense_xtrain_tfidf.shape[1])
t_x, v_x, t_y, v_y = model_selection.train_test_split(dense_xtrain_tfidf, train_y, test_size=0.1, random_state=42)

cls_SNN = train_model(cls_SNN, 
                      feature_vector_train = t_x, 
                      train_label = t_y,
                      feature_vector_valid = v_x,
                      valid_label = v_y,
                      is_neural_net = 1,
                      save_model_path='./cls_SNN.h5',
                      epochs = 20)
# Out:
# 2024-01-23 02:32:18.548708: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 651840000 exceeds 10% of free system memory.
# 2024-01-23 02:32:19.171367: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 651840000 exceeds 10% of free system memory.
# Epoch 1/20
# 2024-01-23 02:32:20.172541: I external/local_xla/xla/service/service.cc:168] XLA service 0x7fc2cc766da0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-01-23 02:32:20.172560: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3060, Compute Capability 8.6
# 2024-01-23 02:32:20.193162: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-01-23 02:32:20.222092: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8902
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1705973540.279057   11653 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1001/1019 [============================>.] - ETA: 0s - loss: 0.0585 - accuracy: 0.9839
# 2024-01-23 02:32:22.272325: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 72440000 exceeds 10% of free system memory.
# 2024-01-23 02:32:22.357073: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 72440000 exceeds 10% of free system memory.
# 1019/1019 [==============================] - 3s 2ms/step - loss: 0.0577 - accuracy: 0.9841 - val_loss: 0.0168 - val_accuracy: 0.9950
# Epoch 2/20
#    1/1019 [..............................] - ETA: 3s - loss: 0.0037 - accuracy: 1.0000
# /home/syntax_error/.pyenv/versions/3.10.13/lib/python3.10/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1019/1019 [==============================] - 2s 2ms/step - loss: 0.0068 - accuracy: 0.9984 - val_loss: 0.0169 - val_accuracy: 0.9945
# Epoch 3/20
# 1019/1019 [==============================] - 2s 2ms/step - loss: 0.0025 - accuracy: 0.9996 - val_loss: 0.0190 - val_accuracy: 0.9931
# Epoch 4/20
# 1019/1019 [==============================] - 2s 2ms/step - loss: 9.8926e-04 - accuracy: 0.9998 - val_loss: 0.0186 - val_accuracy: 0.9939
# Epoch 5/20
# 1019/1019 [==============================] - 2s 2ms/step - loss: 6.1718e-04 - accuracy: 0.9999 - val_loss: 0.0234 - val_accuracy: 0.9934
# Epoch 6/20
# 1019/1019 [==============================] - 2s 2ms/step - loss: 3.8010e-04 - accuracy: 0.9999 - val_loss: 0.0221 - val_accuracy: 0.9931

# %%
cls_SNN.predict(csr_matrix.toarray(xtest_tfidf)[:10])
# Out:
# 1/1 [==============================] - 0s 57ms/step
# array([[2.2616058e-03, 9.9773836e-01],
#        [2.7190879e-05, 9.9997282e-01],
#        [9.9572158e-01, 4.2783404e-03],
#        [4.9146689e-03, 9.9508530e-01],
#        [1.5315385e-05, 9.9998474e-01],
#        [7.5860751e-01, 2.4139254e-01],
#        [8.3270706e-06, 9.9999166e-01],
#        [9.9996829e-01, 3.1740437e-05],
#        [9.9974066e-01, 2.5933378e-04],
#        [5.6365654e-05, 9.9994361e-01]], dtype=float32)

# %%
y_preds, y_probs, cm, fpr, tpr, roc_auc = evaluate_model(cls_SNN,
                                                         csr_matrix.toarray(xtest_tfidf), test_y,
                                                         is_neural_net = 1,
                                                         num_classes = 2)
# Out:
#  72/283 [======>.......................] - ETA: 0s
# 2024-01-23 02:32:32.287180: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 181080000 exceeds 10% of free system memory.
# 283/283 [==============================] - 0s 782us/step
# [[2.2616067e-03 9.9773836e-01]
#  [2.7190854e-05 9.9997282e-01]
#  [9.9572158e-01 4.2783404e-03]
#  ...
#  [1.8234086e-03 9.9817657e-01]
#  [9.9833870e-01 1.6612229e-03]
#  [1.8897157e-05 9.9998105e-01]]

# %% [markdown]
# ## Deep Neural Networks
# Deep Neural Networks are more complex neural networks in which the hidden layers performs much more complex operations than simple sigmoid or relu activations. Different types of deep learning models can be applied in text classification problems.
#
# ![](./imgs/OH3gI.png)
# ### Convolutional Neural Network
# In Convolutional neural networks (CNN), convolutions over the input layer are used to compute the output. This results in local connections, where each region of the input is connected to a neuron in the output. Each layer applies different filters and combines their results.
# ![](./imgs/cnnimage.png)

# %%
def create_cnn():
    # Add an Input Layer
    input_layer = layers.Input((70, ))

    # Add the word embedding Layer
    embedding_layer = layers.Embedding(len(word_index) + 1, 300, weights=[embedding_matrix], trainable=False)(input_layer)
    embedding_layer = layers.SpatialDropout1D(0.3)(embedding_layer)

    # Add the convolutional Layer
    conv_layer = layers.Convolution1D(100, 3, activation="relu")(embedding_layer)

    # Add the pooling Layer
    pooling_layer = layers.GlobalMaxPool1D()(conv_layer)

    # Add the output Layers
    output_layer1 = layers.Dense(50, activation="relu")(pooling_layer)
    output_layer1 = layers.Dropout(0.25)(output_layer1)
    output_layer = layers.Dense(2, activation="softmax")(output_layer1)

    classifier = models.Model(inputs = input_layer, outputs = output_layer)
    classifier.compile(optimizer=optimizers.Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    
    return classifier

# %%
t_x, v_x, t_y, v_y = model_selection.train_test_split(train_seq_x, train_y, test_size=0.1, random_state=42)
cls_CNN = create_cnn()
cls_CNN = train_model(cls_CNN, 
                      feature_vector_train = t_x, 
                      train_label = t_y,
                      feature_vector_valid = v_x,
                      valid_label = v_y,
                      is_neural_net = 1,
                      save_model_path='./cls_CNN.h5',
                      epochs = 20)
# Out:
# Epoch 1/20
# 1019/1019 [==============================] - ETA: 0s - loss: 0.2133 - accuracy: 0.9165
# /home/syntax_error/.pyenv/versions/3.10.13/lib/python3.10/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1019/1019 [==============================] - 5s 4ms/step - loss: 0.2133 - accuracy: 0.9165 - val_loss: 0.0887 - val_accuracy: 0.9705
# Epoch 2/20
# 1019/1019 [==============================] - 2s 2ms/step - loss: 0.0979 - accuracy: 0.9651 - val_loss: 0.1242 - val_accuracy: 0.9558
# Epoch 3/20
# 1019/1019 [==============================] - 4s 4ms/step - loss: 0.0676 - accuracy: 0.9759 - val_loss: 0.0599 - val_accuracy: 0.9809
# Epoch 4/20
# 1019/1019 [==============================] - 2s 2ms/step - loss: 0.0490 - accuracy: 0.9833 - val_loss: 0.0872 - val_accuracy: 0.9705
# Epoch 5/20
# 1019/1019 [==============================] - 3s 3ms/step - loss: 0.0397 - accuracy: 0.9865 - val_loss: 0.0611 - val_accuracy: 0.9809
# Epoch 6/20
# 1019/1019 [==============================] - 3s 3ms/step - loss: 0.0339 - accuracy: 0.9879 - val_loss: 0.0634 - val_accuracy: 0.9809
# Epoch 7/20
# 1019/1019 [==============================] - 3s 3ms/step - loss: 0.0288 - accuracy: 0.9899 - val_loss: 0.1369 - val_accuracy: 0.9633
# Epoch 8/20
# 1019/1019 [==============================] - 3s 2ms/step - loss: 0.0263 - accuracy: 0.9903 - val_loss: 0.0814 - val_accuracy: 0.9798

# %%
y_preds, y_probs, cm, fpr, tpr, roc_auc = evaluate_model(cls_CNN,
                                                         test_seq_x, test_y,
                                                         is_neural_net = 1,
                                                         num_classes = 2)
# Out:
#   1/283 [..............................] - ETA: 11s
# 283/283 [==============================] - 0s 1ms/step
# [[1.4615024e-03 9.9853849e-01]
#  [2.3295879e-03 9.9767035e-01]
#  [9.9759918e-01 2.4008160e-03]
#  ...
#  [2.1566625e-03 9.9784338e-01]
#  [9.9906272e-01 9.3731110e-04]
#  [2.5627492e-02 9.7437257e-01]]

# %% [markdown]
# ### Recurrent Neural Network – LSTM
# Unlike Feed-forward neural networks in which activation outputs are propagated only in one direction, the activation outputs from neurons propagate in both directions (from inputs to outputs and from outputs to inputs) in Recurrent Neural Networks. This creates loops in the neural network architecture which acts as a ‘memory state’ of the neurons. This state allows the neurons an ability to remember what have been learned so far.
#
# The memory state in RNNs gives an advantage over traditional neural networks but a problem called Vanishing Gradient is associated with them. In this problem, while learning with a large number of layers, it becomes really hard for the network to learn and tune the parameters of the earlier layers. To address this problem, A new type of RNNs called LSTMs (Long Short Term Memory) Models have been developed.
#
# ![](./imgs/bptt-768x313.png)

# %%
def create_rnn_lstm():
    # Add an Input Layer
    input_layer = layers.Input((70, ))

    # Add the word embedding Layer
    embedding_layer = layers.Embedding(len(word_index) + 1, 300, weights=[embedding_matrix], trainable=False)(input_layer)
    embedding_layer = layers.SpatialDropout1D(0.3)(embedding_layer)

    # Add the LSTM Layer
    lstm_layer = layers.LSTM(100)(embedding_layer)

    # Add the output Layers
    output_layer1 = layers.Dense(50, activation="relu")(lstm_layer)
    output_layer1 = layers.Dropout(0.25)(output_layer1)
    output_layer2 = layers.Dense(2, activation="softmax")(output_layer1)

    # Compile the model
    model = models.Model(inputs=input_layer, outputs=output_layer2)
    model.compile(optimizer=optimizers.Adam(), loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    
    return model

# %%
t_x, v_x, t_y, v_y = model_selection.train_test_split(train_seq_x, train_y, test_size=0.1, random_state=42)
cls_LSTM = create_rnn_lstm()
cls_LSTM = train_model(cls_LSTM, 
                      feature_vector_train = t_x, 
                      train_label = t_y,
                      feature_vector_valid = v_x,
                      valid_label = v_y,
                      is_neural_net = 1,
                      save_model_path='./cls_LSTM.h5',
                      epochs = 20)
# Out:
# Epoch 1/20
# 1009/1019 [============================>.] - ETA: 0s - loss: 0.3017 - accuracy: 0.8768
# /home/syntax_error/.pyenv/versions/3.10.13/lib/python3.10/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1019/1019 [==============================] - 7s 6ms/step - loss: 0.3019 - accuracy: 0.8768 - val_loss: 0.1946 - val_accuracy: 0.9373
# Epoch 2/20
# 1019/1019 [==============================] - 5s 5ms/step - loss: 0.2069 - accuracy: 0.9192 - val_loss: 0.2248 - val_accuracy: 0.9205
# Epoch 3/20
# 1019/1019 [==============================] - 6s 6ms/step - loss: 0.1739 - accuracy: 0.9348 - val_loss: 0.1301 - val_accuracy: 0.9531
# Epoch 4/20
# 1019/1019 [==============================] - 6s 5ms/step - loss: 0.1516 - accuracy: 0.9435 - val_loss: 0.1217 - val_accuracy: 0.9536
# Epoch 5/20
# 1019/1019 [==============================] - 6s 6ms/step - loss: 0.1295 - accuracy: 0.9539 - val_loss: 0.1021 - val_accuracy: 0.9622
# Epoch 6/20
# 1019/1019 [==============================] - 6s 6ms/step - loss: 0.1118 - accuracy: 0.9585 - val_loss: 0.0925 - val_accuracy: 0.9641
# Epoch 7/20
# 1019/1019 [==============================] - 5s 5ms/step - loss: 0.1001 - accuracy: 0.9645 - val_loss: 0.0929 - val_accuracy: 0.9644
# Epoch 8/20
# 1019/1019 [==============================] - 6s 6ms/step - loss: 0.0885 - accuracy: 0.9683 - val_loss: 0.0910 - val_accuracy: 0.9696
# Epoch 9/20
# 1019/1019 [==============================] - 6s 6ms/step - loss: 0.0776 - accuracy: 0.9718 - val_loss: 0.0809 - val_accuracy: 0.9718
# Epoch 10/20
# 1019/1019 [==============================] - 6s 6ms/step - loss: 0.0694 - accuracy: 0.9751 - val_loss: 0.0738 - val_accuracy: 0.9735
# Epoch 11/20
# 1019/1019 [==============================] - 6s 6ms/step - loss: 0.0629 - accuracy: 0.9781 - val_loss: 0.0697 - val_accuracy: 0.9763
# Epoch 12/20
# 1019/1019 [==============================] - 5s 5ms/step - loss: 0.0540 - accuracy: 0.9811 - val_loss: 0.0761 - val_accuracy: 0.9738
# Epoch 13/20
# 1019/1019 [==============================] - 5s 5ms/step - loss: 0.0502 - accuracy: 0.9823 - val_loss: 0.0990 - val_accuracy: 0.9740
# Epoch 14/20
# 1019/1019 [==============================] - 5s 5ms/step - loss: 0.0420 - accuracy: 0.9845 - val_loss: 0.0829 - val_accuracy: 0.9752
# Epoch 15/20
# 1019/1019 [==============================] - 5s 5ms/step - loss: 0.0385 - accuracy: 0.9865 - val_loss: 0.0808 - val_accuracy: 0.9765
# Epoch 16/20
# 1019/1019 [==============================] - 6s 6ms/step - loss: 0.0351 - accuracy: 0.9874 - val_loss: 0.0697 - val_accuracy: 0.9763
# Epoch 17/20
# 1019/1019 [==============================] - 5s 5ms/step - loss: 0.0332 - accuracy: 0.9885 - val_loss: 0.0760 - val_accuracy: 0.9732
# Epoch 18/20
# 1019/1019 [==============================] - 5s 5ms/step - loss: 0.0285 - accuracy: 0.9894 - val_loss: 0.1032 - val_accuracy: 0.9716
# Epoch 19/20
# 1019/1019 [==============================] - 5s 5ms/step - loss: 0.0260 - accuracy: 0.9907 - val_loss: 0.0854 - val_accuracy: 0.9763
# Epoch 20/20
# 1019/1019 [==============================] - 5s 5ms/step - loss: 0.0227 - accuracy: 0.9921 - val_loss: 0.1267 - val_accuracy: 0.9760

# %%
y_preds, y_probs, cm, fpr, tpr, roc_auc = evaluate_model(cls_LSTM,
                                                         test_seq_x, test_y,
                                                         is_neural_net = 1,
                                                         num_classes = 2)
# Out:
# 283/283 [==============================] - 2s 2ms/step
# [[1.9257170e-05 9.9998069e-01]
#  [6.6605857e-08 9.9999988e-01]
#  [9.9994051e-01 5.9451544e-05]
#  ...
#  [2.1774202e-08 1.0000000e+00]
#  [9.9999595e-01 4.1088242e-06]
#  [8.8459266e-05 9.9991155e-01]]

# %% [markdown]
# ### Recurrent Neural Network – GRU
# Gated Recurrent Units are another form of recurrent neural networks. Lets add a layer of GRU instead of LSTM in our network.

# %%
def create_rnn_gru():
    # Add an Input Layer
    input_layer = layers.Input((70, ))

    # Add the word embedding Layer
    embedding_layer = layers.Embedding(len(word_index) + 1, 300, weights=[embedding_matrix], trainable=False)(input_layer)
    embedding_layer = layers.SpatialDropout1D(0.3)(embedding_layer)

    # Add the GRU Layer
    lstm_layer = layers.GRU(100)(embedding_layer)

    # Add the output Layers
    output_layer1 = layers.Dense(50, activation="relu")(lstm_layer)
    output_layer1 = layers.Dropout(0.25)(output_layer1)
    output_layer2 = layers.Dense(2, activation="softmax")(output_layer1)

    # Compile the model
    model = models.Model(inputs=input_layer, outputs=output_layer2)
    model.compile(optimizer=optimizers.Adam(), loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    
    return model

# %%
t_x, v_x, t_y, v_y = model_selection.train_test_split(train_seq_x, train_y, test_size=0.1, random_state=42)
cls_GRU = create_rnn_gru()
cls_GRU = train_model(cls_GRU, 
                      feature_vector_train = t_x, 
                      train_label = t_y,
                      feature_vector_valid = v_x,
                      valid_label = v_y,
                      is_neural_net = 1,
                      save_model_path='./cls_GRU.h5',
                      epochs = 20)
# Out:
# Epoch 1/20
# 1017/1019 [============================>.] - ETA: 0s - loss: 0.2982 - accuracy: 0.8744
# /home/syntax_error/.pyenv/versions/3.10.13/lib/python3.10/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1019/1019 [==============================] - 7s 6ms/step - loss: 0.2979 - accuracy: 0.8746 - val_loss: 0.1594 - val_accuracy: 0.9393
# Epoch 2/20
# 1019/1019 [==============================] - 5s 5ms/step - loss: 0.1834 - accuracy: 0.9280 - val_loss: 0.1208 - val_accuracy: 0.9578
# Epoch 3/20
# 1019/1019 [==============================] - 5s 5ms/step - loss: 0.1452 - accuracy: 0.9467 - val_loss: 0.1025 - val_accuracy: 0.9636
# Epoch 4/20
# 1019/1019 [==============================] - 5s 5ms/step - loss: 0.1155 - accuracy: 0.9565 - val_loss: 0.0999 - val_accuracy: 0.9649
# Epoch 5/20
# 1019/1019 [==============================] - 6s 5ms/step - loss: 0.0971 - accuracy: 0.9646 - val_loss: 0.0849 - val_accuracy: 0.9713
# Epoch 6/20
# 1019/1019 [==============================] - 5s 5ms/step - loss: 0.0800 - accuracy: 0.9719 - val_loss: 0.0993 - val_accuracy: 0.9652
# Epoch 7/20
# 1019/1019 [==============================] - 6s 6ms/step - loss: 0.0675 - accuracy: 0.9760 - val_loss: 0.0719 - val_accuracy: 0.9768
# Epoch 8/20
# 1019/1019 [==============================] - 5s 5ms/step - loss: 0.0591 - accuracy: 0.9790 - val_loss: 0.0880 - val_accuracy: 0.9694
# Epoch 9/20
# 1019/1019 [==============================] - 5s 5ms/step - loss: 0.0517 - accuracy: 0.9814 - val_loss: 0.0745 - val_accuracy: 0.9765
# Epoch 10/20
# 1019/1019 [==============================] - 5s 5ms/step - loss: 0.0429 - accuracy: 0.9853 - val_loss: 0.0770 - val_accuracy: 0.9763
# Epoch 11/20
# 1019/1019 [==============================] - 5s 5ms/step - loss: 0.0409 - accuracy: 0.9850 - val_loss: 0.0828 - val_accuracy: 0.9757
# Epoch 12/20
# 1019/1019 [==============================] - 5s 5ms/step - loss: 0.0321 - accuracy: 0.9888 - val_loss: 0.0768 - val_accuracy: 0.9768

# %%
y_preds, y_probs, cm, fpr, tpr, roc_auc = evaluate_model(cls_GRU,
                                                         test_seq_x, test_y,
                                                         is_neural_net = 1,
                                                         num_classes = 2)
# Out:
# 283/283 [==============================] - 1s 2ms/step
# [[1.0739618e-03 9.9892598e-01]
#  [2.9827622e-04 9.9970168e-01]
#  [9.7680640e-01 2.3193574e-02]
#  ...
#  [2.4880287e-03 9.9751198e-01]
#  [9.9816847e-01 1.8314673e-03]
#  [8.5334472e-02 9.1466552e-01]]

# %% [markdown]
# ### Bidirectional RNN
# RNN layers can be wrapped in Bidirectional layers as well. Lets wrap our GRU layer in bidirectional layer.

# %%
def create_bidirectional_rnn():
    # Add an Input Layer
    input_layer = layers.Input((70, ))

    # Add the word embedding Layer
    embedding_layer = layers.Embedding(len(word_index) + 1, 300, weights=[embedding_matrix], trainable=False)(input_layer)
    embedding_layer = layers.SpatialDropout1D(0.3)(embedding_layer)

    # Add the LSTM Layer
    lstm_layer = layers.Bidirectional(layers.GRU(100))(embedding_layer)

    # Add the output Layers
    output_layer1 = layers.Dense(50, activation="relu")(lstm_layer)
    output_layer1 = layers.Dropout(0.25)(output_layer1)
    output_layer2 = layers.Dense(2, activation="softmax")(output_layer1)

    # Compile the model
    model = models.Model(inputs=input_layer, outputs=output_layer2)
    model.compile(optimizer=optimizers.Adam(), loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    
    return model

# %%
t_x, v_x, t_y, v_y = model_selection.train_test_split(train_seq_x, train_y, test_size=0.1, random_state=42)
cls_BRNN = create_rnn_gru()
cls_BRNN = train_model(cls_BRNN, 
                      feature_vector_train = t_x, 
                      train_label = t_y,
                      feature_vector_valid = v_x,
                      valid_label = v_y,
                      is_neural_net = 1,
                      save_model_path='./cls_BRNN.h5',
                      epochs = 20)
# Out:
# Epoch 1/20
# 1016/1019 [============================>.] - ETA: 0s - loss: 0.2985 - accuracy: 0.8746
# /home/syntax_error/.pyenv/versions/3.10.13/lib/python3.10/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1019/1019 [==============================] - 7s 6ms/step - loss: 0.2983 - accuracy: 0.8748 - val_loss: 0.1672 - val_accuracy: 0.9382
# Epoch 2/20
# 1019/1019 [==============================] - 5s 5ms/step - loss: 0.1843 - accuracy: 0.9285 - val_loss: 0.1271 - val_accuracy: 0.9495
# Epoch 3/20
# 1019/1019 [==============================] - 5s 5ms/step - loss: 0.1448 - accuracy: 0.9464 - val_loss: 0.1083 - val_accuracy: 0.9633
# Epoch 4/20
# 1019/1019 [==============================] - 5s 5ms/step - loss: 0.1180 - accuracy: 0.9558 - val_loss: 0.0970 - val_accuracy: 0.9647
# Epoch 5/20
# 1019/1019 [==============================] - 6s 6ms/step - loss: 0.0970 - accuracy: 0.9646 - val_loss: 0.0896 - val_accuracy: 0.9674
# Epoch 6/20
# 1019/1019 [==============================] - 5s 5ms/step - loss: 0.0821 - accuracy: 0.9709 - val_loss: 0.0761 - val_accuracy: 0.9740
# Epoch 7/20
# 1019/1019 [==============================] - 5s 5ms/step - loss: 0.0693 - accuracy: 0.9752 - val_loss: 0.0730 - val_accuracy: 0.9732
# Epoch 8/20
# 1019/1019 [==============================] - 6s 6ms/step - loss: 0.0598 - accuracy: 0.9791 - val_loss: 0.0695 - val_accuracy: 0.9746
# Epoch 9/20
# 1019/1019 [==============================] - 5s 4ms/step - loss: 0.0499 - accuracy: 0.9828 - val_loss: 0.0752 - val_accuracy: 0.9757
# Epoch 10/20
# 1019/1019 [==============================] - 5s 5ms/step - loss: 0.0441 - accuracy: 0.9835 - val_loss: 0.0731 - val_accuracy: 0.9771
# Epoch 11/20
# 1019/1019 [==============================] - 5s 5ms/step - loss: 0.0401 - accuracy: 0.9855 - val_loss: 0.0809 - val_accuracy: 0.9790
# Epoch 12/20
# 1019/1019 [==============================] - 5s 5ms/step - loss: 0.0338 - accuracy: 0.9881 - val_loss: 0.0832 - val_accuracy: 0.9760
# Epoch 13/20
# 1019/1019 [==============================] - 5s 5ms/step - loss: 0.0295 - accuracy: 0.9897 - val_loss: 0.0913 - val_accuracy: 0.9779

# %%
y_preds, y_probs, cm, fpr, tpr, roc_auc = evaluate_model(cls_BRNN,
                                                         test_seq_x, test_y,
                                                         is_neural_net = 1,
                                                         num_classes = 2)
# Out:
# 283/283 [==============================] - 1s 2ms/step
# [[2.3258367e-04 9.9976736e-01]
#  [5.9217596e-06 9.9999404e-01]
#  [9.9134010e-01 8.6598881e-03]
#  ...
#  [7.6061704e-05 9.9992394e-01]
#  [9.9919754e-01 8.0248504e-04]
#  [1.0616578e-02 9.8938340e-01]]

# %% [markdown]
# ### Recurrent Convolutional Neural Network
# Once the essential architectures have been tried out, one can try different variants of these layers such as recurrent convolutional neural network. Another variants can be:
#
# 1. Hierarichial Attention Networks
# 2. Sequence to Sequence Models with Attention
# 3. Bidirectional Recurrent Convolutional Neural Networks
# 4. CNNs and RNNs with more number of layers

# %%
def create_rcnn():
    # Add an Input Layer
    input_layer = layers.Input((70, ))

    # Add the word embedding Layer
    embedding_layer = layers.Embedding(len(word_index) + 1, 300, weights=[embedding_matrix], trainable=False)(input_layer)
    embedding_layer = layers.SpatialDropout1D(0.3)(embedding_layer)
    
    # Add the recurrent layer
    rnn_layer = layers.Bidirectional(layers.GRU(50, return_sequences=True))(embedding_layer)
    
    # Add the convolutional Layer
    conv_layer = layers.Convolution1D(100, 3, activation="relu")(embedding_layer)

    # Add the pooling Layer
    pooling_layer = layers.GlobalMaxPool1D()(conv_layer)

    # Add the output Layers
    output_layer1 = layers.Dense(50, activation="relu")(pooling_layer)
    output_layer1 = layers.Dropout(0.25)(output_layer1)
    output_layer2 = layers.Dense(2, activation="softmax")(output_layer1)

    # Compile the model
    model = models.Model(inputs=input_layer, outputs=output_layer2)
    model.compile(optimizer=optimizers.Adam(), loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    
    return model

# %%
t_x, v_x, t_y, v_y = model_selection.train_test_split(train_seq_x, train_y, test_size=0.1, random_state=42)
cls_RCNN = create_rcnn()
cls_RCNN = train_model(cls_RCNN, 
                      feature_vector_train = t_x, 
                      train_label = t_y,
                      feature_vector_valid = v_x,
                      valid_label = v_y,
                      is_neural_net = 1,
                      save_model_path='./cls_RCNN.h5',
                      epochs = 20)
# Out:
# Epoch 1/20
# 1012/1019 [============================>.] - ETA: 0s - loss: 0.2167 - accuracy: 0.9120
# /home/syntax_error/.pyenv/versions/3.10.13/lib/python3.10/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1019/1019 [==============================] - 4s 4ms/step - loss: 0.2162 - accuracy: 0.9122 - val_loss: 0.0883 - val_accuracy: 0.9666
# Epoch 2/20
# 1019/1019 [==============================] - 4s 4ms/step - loss: 0.0975 - accuracy: 0.9660 - val_loss: 0.0670 - val_accuracy: 0.9776
# Epoch 3/20
# 1019/1019 [==============================] - 4s 4ms/step - loss: 0.0651 - accuracy: 0.9776 - val_loss: 0.0649 - val_accuracy: 0.9798
# Epoch 4/20
# 1019/1019 [==============================] - 3s 2ms/step - loss: 0.0518 - accuracy: 0.9814 - val_loss: 0.0667 - val_accuracy: 0.9771
# Epoch 5/20
# 1019/1019 [==============================] - 2s 2ms/step - loss: 0.0388 - accuracy: 0.9862 - val_loss: 0.0696 - val_accuracy: 0.9765
# Epoch 6/20
# 1019/1019 [==============================] - 3s 3ms/step - loss: 0.0358 - accuracy: 0.9876 - val_loss: 0.0568 - val_accuracy: 0.9776
# Epoch 7/20
# 1019/1019 [==============================] - 3s 3ms/step - loss: 0.0290 - accuracy: 0.9899 - val_loss: 0.0640 - val_accuracy: 0.9812
# Epoch 8/20
# 1019/1019 [==============================] - 2s 2ms/step - loss: 0.0266 - accuracy: 0.9904 - val_loss: 0.0707 - val_accuracy: 0.9812
# Epoch 9/20
# 1019/1019 [==============================] - 3s 3ms/step - loss: 0.0264 - accuracy: 0.9904 - val_loss: 0.0602 - val_accuracy: 0.9801
# Epoch 10/20
# 1019/1019 [==============================] - 2s 2ms/step - loss: 0.0216 - accuracy: 0.9926 - val_loss: 0.0638 - val_accuracy: 0.9787
# Epoch 11/20
# 1019/1019 [==============================] - 2s 2ms/step - loss: 0.0218 - accuracy: 0.9927 - val_loss: 0.0721 - val_accuracy: 0.9798

# %%
y_preds, y_probs, cm, fpr, tpr, roc_auc = evaluate_model(cls_RCNN,
                                                         test_seq_x, test_y,
                                                         is_neural_net = 1,
                                                         num_classes = 2)
# Out:
#   1/283 [..............................] - ETA: 12s
# 283/283 [==============================] - 0s 768us/step
# [[1.22006706e-04 9.99877930e-01]
#  [6.08092114e-06 9.99993920e-01]
#  [9.98605430e-01 1.39462354e-03]
#  ...
#  [7.38758354e-06 9.99992609e-01]
#  [9.96275544e-01 3.72451055e-03]
#  [2.58333777e-04 9.99741614e-01]]

# %%
def load_CNN_model(model_path):
    """
    Load a Keras model from a specified path.

    Parameters:
    - model_path (str): Full path to the saved model file (.h5).

    Returns:
    - model: Loaded Keras model.
    """
    try:
        model = models.load_model(model_path)
        print(f'Model loaded successfully from {model_path}')
        return model
    except Exception as e:
        print(f'Error loading the model from {model_path}: {e}')
        return None

# %%
load2 = 1

if load2:
    # cls_MNB_CV, cls_MNB_tfidf, cls_MNB_tfidf_ngram, cls_MNB_tfidf_ngram_char = None, None, None, None
    # cls_LMLR_CV, cls_LMLR_tfidf, cls_LMLR_tfidf_ngram, cls_LMLR_tfidf_ngram_char = None, None, None, None
    # cls_RF_CV, cls_RF_tfidf = None, None
    # cls_EGB_CV, cls_EGB_tfidf, cls_EGB_tfidf_ngram_char = None, None, None
    my_CNN_models = []

    CNN_model_paths = ['./cls_SNN.h5', './cls_CNN.h5', './cls_LSTM.h5', './cls_GRU.h5',
                './cls_BRNN.h5', './cls_RCNN.h5']

    for path in CNN_model_paths:
        my_CNN_models.append(load_CNN_model(path))
# Out:
# Model loaded successfully from ./cls_SNN.h5
# Model loaded successfully from ./cls_CNN.h5
# Model loaded successfully from ./cls_LSTM.h5
# Model loaded successfully from ./cls_GRU.h5
# Model loaded successfully from ./cls_BRNN.h5
# Model loaded successfully from ./cls_RCNN.h5

# %%
CNN_model_names = ['cls_SNN', 'cls_CNN', 'cls_LSTM', 'cls_GRU',
                'cls_BRNN', 'cls_RCNN']
x_data = [csr_matrix.toarray(xtest_tfidf), test_seq_x, test_seq_x, test_seq_x,
          test_seq_x, test_seq_x]

y_preds, y_probs, cm, fpr, tpr, roc_auc = evaluate_models(my_CNN_models,
                                                          CNN_model_names,
                                                          x_data, test_y,
                                                          is_neural_net = 1,
                                                          num_classes = 2,
                                                          nrows = 2,
                                                          cm_figsize=(18, 15),
                                                          roc_alpha= .7,
                                                          save_fig = 1,
                                                          label_names = ['orig_text_train_NN',
                                                                         'orig_text_train_NN'])
# Out:
# 283/283 [==============================] - 0s 775us/step
# 283/283 [==============================] - 0s 760us/step
# 283/283 [==============================] - 1s 2ms/step
# 283/283 [==============================] - 1s 2ms/step
# 283/283 [==============================] - 1s 2ms/step
# 283/283 [==============================] - 0s 748us/step
# /tmp/ipykernel_11140/312248327.py:200: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /tmp/ipykernel_11140/312248327.py:201: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   roc_fig.show()
